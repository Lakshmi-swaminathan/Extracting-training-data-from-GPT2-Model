# %%
"""
Generate samples with GPT-2 and filter out those that are likely to be
memorized samples from the training set.
"""

import logging
logging.basicConfig(level='ERROR')

import argparse
import numpy as np
from pprint import pprint
import sys
import torch
import zlib
from transformers import GPT2Tokenizer, GPT2LMHeadModel
from tqdm import tqdm

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

def calculatePerplexity(sentence, model, tokenizer):
    """
    exp(loss)
    """
    input_ids = torch.tensor(tokenizer.encode(sentence)).unsqueeze(0)
    input_ids = input_ids.to(device)
    with torch.no_grad():
        outputs = model(input_ids, labels=input_ids)
    loss, logits = outputs[:2]
    return torch.exp(loss)

def print_best(metric, samples, name1, scores1, name2=None, scores2=None, n=10):
    """
    print the `n` best samples according to the given `metric`
    """
    idxs = np.argsort(metric)[::-1][:n]

    for i, idx in enumerate(idxs):
        if scores2 is not None:
            print(f"{i+1}: {name1}={scores1[idx]:.3f}, {name2}={scores2[idx]:.3f}, score={metric[idx]:.3f}")
        else:
            print(f"{i+1}: {name1}={scores1[idx]:.3f}, , score={metric[idx]:.3f}")

        print()
        #for line in samples[idx].split("\n"):
        #    print(f"\t {line.rstrip()}")
        pprint(samples[idx])
        print()
        print()


def parse_commoncrawl(wet_file):
    """
    Quick and ugly parsing of a WET file.
    Tested for the May 2021 crawl.
    """
    with open(wet_file) as f:
        lines = f.readlines()

    start_idxs = [i for i in range(len(lines)) if "WARC/1.0" in lines[i]]

    all_eng = ""

    count_eng = 0
    for i in range(len(start_idxs)-1):
        start = start_idxs[i]
        end = start_idxs[i+1]
        if "WARC-Identified-Content-Language: eng" in lines[start+7]:
            count_eng += 1
            for j in range(start+10, end):
                all_eng += lines[j]

    return all_eng


def main():
    print(f"using device: {device}")

    if args.internet_sampling:
        print("Loading common crawl...")
        cc = parse_commoncrawl(args.wet_file)

    # number of tokens to generate
    seq_len = 256

    # sample from the top_k tokens output by the model
    top_k = 40

    print("Loading GPT2...")
    tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
    tokenizer.padding_side = "left"
    tokenizer.pad_token = tokenizer.eos_token

    model1 = GPT2LMHeadModel.from_pretrained('gpt2-xl', return_dict=True).to(device)
    model1.config.pad_token_id = model1.config.eos_token_id
    model2 = GPT2LMHeadModel.from_pretrained('gpt2', return_dict=True).to(device)
    model1.eval()
    model2.eval()

    samples = []
    scores = {"XL": [], "S": [], "Lower": [], "zlib": []}

    num_batches = int(np.ceil(args.N / args.batch_size))
    with tqdm(total=args.N) as pbar:
        for i in range(num_batches):
            # encode the prompts
            if args.internet_sampling:
                # pick a random 10-token prompt in common crawl

                input_len = 10
                input_ids = []
                attention_mask = []

                while len(input_ids) < args.batch_size:
                    # take some random words in common crawl
                    r = np.random.randint(0, len(cc))
                    prompt = " ".join(cc[r:r+100].split(" ")[1:-1])

                    # make sure we get the same number of tokens for each prompt to enable batching
                    inputs = tokenizer(prompt, return_tensors="pt", max_length=input_len, truncation=True)
                    if len(inputs['input_ids'][0]) == input_len:
                        input_ids.append(inputs['input_ids'][0])
                        attention_mask.append(inputs['attention_mask'][0])

                inputs = {'input_ids': torch.stack(input_ids),
                          'attention_mask': torch.stack(attention_mask)}

                # the actual truncated prompts
                prompts = tokenizer.batch_decode(inputs['input_ids'], skip_special_tokens=True)
            else:
                prompts = ["<|endoftext|>"] * args.batch_size
                input_len = 1
                inputs = tokenizer(prompts, return_tensors="pt", padding=True)

            # batch generation
            output_sequences = model1.generate(
                input_ids=inputs['input_ids'].to(device),
                attention_mask=inputs['attention_mask'].to(device),
                max_length=input_len + seq_len,
                do_sample=True,
                top_k=top_k,
                top_p=1.0
            )

            texts = tokenizer.batch_decode(output_sequences, skip_special_tokens=True)

            for text in texts:
                # perplexity of GPT2-XL and GPT2-S
                p1 = calculatePerplexity(text, model1, tokenizer)
                p2 = calculatePerplexity(text, model2, tokenizer)

                # perplexity on lower-case sample
                p_lower = calculatePerplexity(text.lower(), model1, tokenizer)

                # Zlib "entropy" of sample
                zlib_entropy = len(zlib.compress(bytes(text, 'utf-8')))

                samples.append(text)
                scores["XL"].append(p1)
                scores["S"].append(p2)
                scores["Lower"].append(p_lower)
                scores["zlib"].append(zlib_entropy)

            pbar.update(args.batch_size)

    scores["XL"] = np.asarray(scores["XL"])
    scores["S"] = np.asarray(scores["S"])
    scores["Lower"] = np.asarray(scores["Lower"])
    scores["zlib"] = np.asarray(scores["zlib"])

    # Sort by perplexity
    metric = -np.log(scores["XL"])
    print(f"======== top sample by XL perplexity: ========")
    print_best(metric, samples, "PPL", scores["XL"])
    print()
    print()

    # Sort by ratio of log perplexities of S and XL models
    metric = np.log(scores["S"]) / np.log(scores["XL"])
    print(f"======== top sample by ratio of S and XL perplexities: ========")
    print_best(metric, samples, "PPL-XL", scores["XL"], "PPL-S", scores["S"])
    print()
    print()

    # Sort by ratio of log perplexities of lower-case and normal-case perplexities
    metric = np.log(scores["Lower"]) / np.log(scores["XL"])
    print(f"======== top sample by ratio of lower-case and normal-case perplexities: ========")
    print_best(metric, samples, "PPL-XL", scores["XL"], "PPL-XL-Lower", scores["Lower"])
    print()
    print()

    # Sort by ratio of Zlib entropy and XL perplexity
    metric = scores["zlib"] / np.log(scores["XL"])
    print(f"======== top sample by ratio of Zlib entropy and XL perplexity: ========")
    print_best(metric, samples, "PPL-XL", scores["XL"], "Zlib", scores["zlib"])

def parse_arguments(argv):
    parser = argparse.ArgumentParser()
    parser.add_argument('--N', type=int, default=1000, help="Number of samples to generate")
    parser.add_argument('--batch-size', type=int, default=10, help="Batch size for generation")
    parser.add_argument('--internet-sampling', action='store_true', help="condition the generation using commoncrawl")
    parser.add_argument('--wet-file', type=str, default=None, help="path to a commoncrawl WET file")
    return parser.parse_args(argv)

if __name__ == '__main__':
    args = parse_arguments(sys.argv[1:])
    main()
# Out:
# usage: colab_kernel_launcher.py [-h] [--N N] [--batch-size BATCH_SIZE] [--internet-sampling]
#                                 [--wet-file WET_FILE]
# colab_kernel_launcher.py: error: unrecognized arguments: -f /root/.local/share/jupyter/runtime/kernel-e6cdc0db-1380-4fd4-9874-ba45108d275c.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
"""
Generate samples with GPT-2 and filter out those that are likely to be
memorized samples from the training set.
"""

import logging
logging.basicConfig(level='ERROR')

import argparse
import numpy as np
from pprint import pprint
import sys
import torch
import zlib
from transformers import GPT2Tokenizer, GPT2LMHeadModel
from tqdm import tqdm

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def calculatePerplexity(sentence, model, tokenizer):
    """
    exp(loss)
    """
    input_ids = torch.tensor(tokenizer.encode(sentence)).unsqueeze(0)
    input_ids = input_ids.to(device)
    with torch.no_grad():
        outputs = model(input_ids, labels=input_ids)
    loss, logits = outputs[:2]
    return torch.exp(loss)

# %%
def print_best(metric, samples, name1, scores1, name2=None, scores2=None, n=10):
    """
    print the `n` best samples according to the given `metric`
    """
    idxs = np.argsort(metric)[::-1][:n]

    for i, idx in enumerate(idxs):
        if scores2 is not None:
            print(f"{i+1}: {name1}={scores1[idx]:.3f}, {name2}={scores2[idx]:.3f}, score={metric[idx]:.3f}")
        else:
            print(f"{i+1}: {name1}={scores1[idx]:.3f}, , score={metric[idx]:.3f}")

        print()
        #for line in samples[idx].split("\n"):
        #    print(f"\t {line.rstrip()}")
        pprint(samples[idx])
        print()
        print()

# %%
def parse_commoncrawl(wet_file):
    """
    Quick and ugly parsing of a WET file.
    Tested for the May 2021 crawl.
    """
    with open(wet_file) as f:
        lines = f.readlines()

    start_idxs = [i for i in range(len(lines)) if "WARC/1.0" in lines[i]]

    all_eng = ""

    count_eng = 0
    for i in range(len(start_idxs)-1):
        start = start_idxs[i]
        end = start_idxs[i+1]
        if "WARC-Identified-Content-Language: eng" in lines[start+7]:
            count_eng += 1
            for j in range(start+10, end):
                all_eng += lines[j]

    return all_eng

# %%
def main():
    print(f"using device: {device}")

    if args.internet_sampling:
        print("Loading common crawl...")
        cc = parse_commoncrawl(args.wet_file)

    # number of tokens to generate
    seq_len = 256

    # sample from the top_k tokens output by the model
    top_k = 40

    print("Loading GPT2...")
    tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
    tokenizer.padding_side = "left"
    tokenizer.pad_token = tokenizer.eos_token

    model1 = GPT2LMHeadModel.from_pretrained('gpt2-xl', return_dict=True).to(device)
    model1.config.pad_token_id = model1.config.eos_token_id
    model2 = GPT2LMHeadModel.from_pretrained('gpt2', return_dict=True).to(device)
    model1.eval()
    model2.eval()

    samples = []
    scores = {"XL": [], "S": [], "Lower": [], "zlib": []}

    num_batches = int(np.ceil(args.N / args.batch_size))
    with tqdm(total=args.N) as pbar:
        for i in range(num_batches):
            # encode the prompts
            if args.internet_sampling:
                # pick a random 10-token prompt in common crawl

                input_len = 10
                input_ids = []
                attention_mask = []

                while len(input_ids) < args.batch_size:
                    # take some random words in common crawl
                    r = np.random.randint(0, len(cc))
                    prompt = " ".join(cc[r:r+100].split(" ")[1:-1])

                    # make sure we get the same number of tokens for each prompt to enable batching
                    inputs = tokenizer(prompt, return_tensors="pt", max_length=input_len, truncation=True)
                    if len(inputs['input_ids'][0]) == input_len:
                        input_ids.append(inputs['input_ids'][0])
                        attention_mask.append(inputs['attention_mask'][0])

                inputs = {'input_ids': torch.stack(input_ids),
                          'attention_mask': torch.stack(attention_mask)}

                # the actual truncated prompts
                prompts = tokenizer.batch_decode(inputs['input_ids'], skip_special_tokens=True)
            else:
                prompts = ["<|endoftext|>"] * args.batch_size
                input_len = 1
                inputs = tokenizer(prompts, return_tensors="pt", padding=True)

            # batch generation
            output_sequences = model1.generate(
                input_ids=inputs['input_ids'].to(device),
                attention_mask=inputs['attention_mask'].to(device),
                max_length=input_len + seq_len,
                do_sample=True,
                top_k=top_k,
                top_p=1.0
            )

            texts = tokenizer.batch_decode(output_sequences, skip_special_tokens=True)

            for text in texts:
                # perplexity of GPT2-XL and GPT2-S
                p1 = calculatePerplexity(text, model1, tokenizer)
                p2 = calculatePerplexity(text, model2, tokenizer)

                # perplexity on lower-case sample
                p_lower = calculatePerplexity(text.lower(), model1, tokenizer)

                # Zlib "entropy" of sample
                zlib_entropy = len(zlib.compress(bytes(text, 'utf-8')))

                samples.append(text)
                scores["XL"].append(p1)
                scores["S"].append(p2)
                scores["Lower"].append(p_lower)
                scores["zlib"].append(zlib_entropy)

            pbar.update(args.batch_size)

    scores["XL"] = np.asarray(scores["XL"])
    scores["S"] = np.asarray(scores["S"])
    scores["Lower"] = np.asarray(scores["Lower"])
    scores["zlib"] = np.asarray(scores["zlib"])

    # Sort by perplexity
    metric = -np.log(scores["XL"])
    print(f"======== top sample by XL perplexity: ========")
    print_best(metric, samples, "PPL", scores["XL"])
    print()
    print()

    # Sort by ratio of log perplexities of S and XL models
    metric = np.log(scores["S"]) / np.log(scores["XL"])
    print(f"======== top sample by ratio of S and XL perplexities: ========")
    print_best(metric, samples, "PPL-XL", scores["XL"], "PPL-S", scores["S"])
    print()
    print()

    # Sort by ratio of log perplexities of lower-case and normal-case perplexities
    metric = np.log(scores["Lower"]) / np.log(scores["XL"])
    print(f"======== top sample by ratio of lower-case and normal-case perplexities: ========")
    print_best(metric, samples, "PPL-XL", scores["XL"], "PPL-XL-Lower", scores["Lower"])
    print()
    print()

    # Sort by ratio of Zlib entropy and XL perplexity
    metric = scores["zlib"] / np.log(scores["XL"])
    print(f"======== top sample by ratio of Zlib entropy and XL perplexity: ========")
    print_best(metric, samples, "PPL-XL", scores["XL"], "Zlib", scores["zlib"])

# %%
def parse_arguments(argv):
    parser = argparse.ArgumentParser()
    parser.add_argument('--N', type=int, default=1000, help="Number of samples to generate")
    parser.add_argument('--batch-size', type=int, default=10, help="Batch size for generation")
    parser.add_argument('--internet-sampling', action='store_true', help="condition the generation using commoncrawl")
    parser.add_argument('--wet-file', type=str, default=None, help="path to a commoncrawl WET file")
    return parser.parse_args(argv)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python3 extraction.py --N 1000 --batch-size 10
# Out:
# using device: cpu
# Loading GPT2...
# Loaded 983 samples. 17 more samples needed.
# Loaded checkpoint: 983 samples already generated.
# Remaining samples to generate: 17
#   0% 0/17 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 993it [03:25,  4.83it/s]  Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 1986it [06:37,  5.00it/s]
# ======== top sample by XL perplexity: ========
# 1: PPL=5.179, , score=-1.645
#
# ('Preliminary figures show the rate of alcohol-related deaths declined by one '
#  'per cent from 2008-2009 to 2009, and by 6.8 per cent in 2010.\n'
#  '\n'
#  'Alcohol deaths decreased by 0.02 per cent, or five deaths in four years, '
#  'from 2008-2009 to 2009, according to a report from the Ministry of Health '
#  'and Long-Term Care.\n'
#  '\n'
#  'By the end of 2011, there were 1,040 alcohol-related deaths, which means the '
#  'rate of alcohol-linked deaths dropped by 1.6 per cent from 2008.\n'
#  '\n'
#  'Of the 2,957 deaths during that year, nearly one in 10 were under the age of '
#  '35, a percentage that has decreased for all age groups since 2008.\n'
#  '\n'
#  'By 2011, alcohol-related deaths declined one per cent from 2009 for all age '
#  'groups.\n'
#  '\n'
#  'There were 7,917 alcohol-related deaths in Canada in 2010, according to the '
#  'report.\n'
#  '\n'
#  'For the most part, that decrease in deaths comes on the heels of a sharp '
#  'increase in deaths caused by drug and other drug overdoses.\n'
#  '\n'
#  'Overall, drug-related deaths increased by 23 per cent from 2008 to 2009, and '
#  'by 15.5 per cent in 2010.\n'
#  '\n'
#  'The report says that most of')
#
#
# 2: PPL=5.403, , score=-1.687
#
# ('Bryan Cranston has officially signed on to star in a new film, which is now '
#  'being called "The Mummy" in a new report by The Hollywood Reporter.\n'
#  '\n'
#  'There are currently no cast members confirmed for the film, which is '
#  'reportedly titled "The Mummy," but Cranston is working closely with '
#  'production companies and casting directors on the project.\n'
#  '\n'
#  'The film, which will release in theaters in November 2016, is set at a time '
#  'when scientists are uncovering a tomb containing The Mummy, but a team of '
#  'archaeologists comes under attack from an ancient evil. Based on the comic '
#  'book book by Guillermo Del Toro and Brendan Fletcher, "The Mummy" will be '
#  'directed by the team behind "Pacific Rim," J.J. Abrams and Mark Bomback (who '
#  'directed del Toro on "Pan\'s Labyrinth").\n'
#  '\n'
#  '"The Mummy," which was originally reported as coming to theaters as a remake '
#  'of the 1933 original, was originally announced in 2013 as the third '
#  'installment of the "Universal Monsters" series. That will now appear to be '
#  'the only film released under that name, which also includes "Frankenstein," '
#  '"Dr. Jekyll and Mr. Hyde" and "Bride of Frankenstein."')
#
#
# 3: PPL=5.816, , score=-1.761
#
# ('A large number of British Columbia residents are facing eviction from their '
#  'homes because of the wildfires that have ravaged the province.\n'
#  '\n'
#  'CBC News has spoken to a number of people who have faced the threat of '
#  'eviction, with many saying they are willing to leave their homes, but that '
#  "they don't have the resources to do so.\n"
#  '\n'
#  'Shelter B.C. estimates that 2,200 evacuees and more than 100 non-evacuees '
#  'who cannot leave have had their emergency housing applications rejected.\n'
#  '\n'
#  "'I have to sell'\n"
#  '\n'
#  'Lisa MacLean has been forced to make a difficult decision. Her family has '
#  'lived in a two-bedroom apartment in Fort St. John for three decades.\n'
#  '\n'
#  '"My two children are teenagers," said MacLean. "They\'re getting older and I '
#  "have to sell. I don't have the money.\n"
#  '\n'
#  '"They\'re not really in the same frame of mind that I am. They understand '
#  "that we are getting ready to leave. There's tears in my eyes. It's just very "
#  'emotional."\n'
#  '\n'
#  'People in evacuation zones say they are getting desperate.\n'
#  '\n'
#  '"My main priority is my family," said one person who, like other evacuees, '
#  'asked not to be named.\n'
#  '\n')
#
#
# 4: PPL=5.864, , score=-1.769
#
# ('The U.S. Food and Drug Administration on Wednesday moved swiftly to approve '
#  'the first new cancer drug since the Food and Drug Administration (FDA) '
#  'approved the first antidepressant in 1977.\n'
#  '\n'
#  'The drug targets tumors in the breast and blood vessel known as peripheral '
#  'arterial disease that result from a defect in blood vessel growth.\n'
#  '\n'
#  'Patients with PAD have problems in producing and maintaining blood vessel '
#  'walls, especially in the lower legs, neck and in their feet. The condition '
#  'is usually inherited.\n'
#  '\n'
#  "The FDA's approval of Janssen Pharmaceutica's Actonel made it the third drug "
#  "in a year to target PAD, following Janssen's Nivolumab (dolutegravir) "
#  "approved at the end of last year and Novartis' Avastin (ribavirin) approved "
#  'at the end of 2011.\n'
#  '\n'
#  'As FDA Commissioner Margaret Hamburg said, the agency is "getting there" '
#  'with the approval of both drugs.\n'
#  '\n'
#  'The approval of Actonel is based on clinical trials showing that the drug '
#  'reduced the number of lung and breast cancers that develop in about 1 in 4 '
#  'of PAD patients who get it.\n'
#  '\n'
#  'The drug is also shown in cancer patients to reduce the length of their '
#  'survival and the risk')
#
#
# 5: PPL=6.069, , score=-1.803
#
# ('"\n'
#  '\n'
#  '— The Master as he takes on the rest of Team Avatar in "\n'
#  '\n'
#  'The Order of the White Lotus (日居国志, Nankai Sōten?), also known as the Order '
#  'of the White Lotus, the White Lotus (麻鳳官, Kōkōshō?), and the White Lotus '
#  'Army, is a group of powerful Fire Nation military officials who secretly '
#  'helped the Earth Kingdom after the Hundred Year War. The Order was led in '
#  'the Hundred Year War by the current head of the Order, General Iroh.\n'
#  '\n'
#  'Contents show]\n'
#  '\n'
#  'History\n'
#  '\n'
#  'Early\n'
#  '\n'
#  'According to Princess Yue of the Fire Nation, the Order of the White Lotus '
#  'first appeared around three hundred years ago as a group of powerful '
#  "firebenders who used their power to quell the Fire Nation's rebellion. "
#  'Princess Yue said that as a result of their help, the Southern Water Tribe '
#  'and the Earth Kingdom agreed to a cease fire, and the four nations soon '
#  'found peace.\n'
#  '\n'
#  'After the war, a firebender named Zuko decided to create a "sister city" '
#  "named Ember Island, as he was fascinated by the island's fire and the blue "
#  'flame of the Fire Nation.[1]\n')
#
#
# 6: PPL=6.146, , score=-1.816
#
# ('This is the web version of VoxCare, a daily newsletter from Vox on the '
#  "latest twists and turns in America's health care debate. Like what you're "
#  'reading? Sign up to get VoxCare in your inbox here.\n'
#  '\n'
#  "We already talked about John McCain's shocking announcement last night that "
#  'he would vote to open debate on a bill (not an "abortive" bill!) allowing '
#  'for cheaper high-risk pools to cover Americans with preexisting medical '
#  'conditions.\n'
#  '\n'
#  'It was a huge win for the Republicans. McCain had previously called the bill '
#  '"mean-spirited" and threatened to hold up a final vote on the measure unless '
#  'he got a "significant amendment" to his proposal that made it "a little bit '
#  'more appealing for Republicans," which he would not get.\n'
#  '\n'
#  'Now, even if McCain gets a "modest amendment," that doesn\'t guarantee '
#  'anything: It would only help. The bill is "dysfunctional" in other words, '
#  'and it would most likely be fixed through amendments in what is a partisan '
#  'process. What McCain is doing is setting up a process now in which the '
#  'Republicans will have plenty of time to iron out all the kinks in a bill '
#  'which could come up for a final vote in a matter of days.\n'
#  '\n'
#  'What')
#
#
# 7: PPL=6.279, , score=-1.837
#
# ('It takes a special kind of animal to find a way to take out, and it has a '
#  'new best friend in the small town of Wittenau in the German state of '
#  'Mecklenburg-Western Pomerania. A rare species of wolf (Canis lupus) has '
#  'apparently become rarer in the last few decades in the area because of the '
#  'impact of farming, forestry and other man-made causes.\n'
#  '\n'
#  'The recent findings are part of a project financed by the German Science '
#  'Foundation (DFG) and conducted by the Nature Institute and the German Wolf '
#  'Center Mecklenburg-Western Pomerania.\n'
#  '\n'
#  'This rare wolf (Canis lupus lupus) (Photo: Nature Institute)\n'
#  '\n'
#  'The local population of the wolf appears to have been gradually reduced by a '
#  'combination of factors: the wolf population declines as it is hunted for its '
#  'body parts (which include meat, fur and bones), and by a variety or '
#  'human-related activities such as hunting, agriculture, and forest thinning.\n'
#  '\n'
#  'The Nature Institute, along with the Wolf Center Mecklenburg-Western '
#  'Pomerania, analyzed DNA sequences from the remains of the wolf and other '
#  'species living in the area. According to the results, the population decline '
#  'seems likely')
#
#
# 8: PPL=6.304, , score=-1.841
#
# ('Hockey is getting bigger in the U.S.\n'
#  '\n'
#  "The USHL is the nation's oldest professional minor pro men's hockey league. "
#  'The league began operations in 1917 and has grown to 12 teams (all but two '
#  'in the Southeast), with one based in Pennsylvania. The league is not '
#  'affiliated with the NHL or the Canadian Hockey League.\n'
#  '\n'
#  'The league has established a legacy. The USHL has won 14 USHL championships '
#  'since its founding in 1917.\n'
#  '\n'
#  'Here, USA TODAY Sports ranks the 10 best USHL hockey teams to watch for the '
#  '2017-18 season:\n'
#  '\n'
#  'Nestor Cortes, RW, Bloomington Thunder (Northwest Junior Ice Hockey League)\n'
#  '\n'
#  'Cortes helped the Southlake Thunder, who are playing home games at Lake '
#  'Travis Field. He had 30 goals and 67 points in 38 games.\n'
#  '\n'
#  'Nick Schmaltz, RD, Greenville Swamp Rabbits (South Atlantic League)\n'
#  '\n'
#  'Schmaltz made the team and played 11 playoff games with the Greenville '
#  'Rattlers, finishing with seven goals and 16 points. The 22-year-old from '
#  'Lake Stevens, Wash., scored his first career goal in the playoffs.\n'
#  '\n'
#  'Kai Chen, C, Greenville Flying Hawks (Southern Professional Hockey')
#
#
# 9: PPL=6.460, , score=-1.866
#
# ('The National Science Foundation (NSF) is committed to supporting efforts '
#  'made by the federal government, state and local governments, and the private '
#  'sector to create, retain, and grow strong scientific, engineering, and '
#  'technological education (STEM) programs, facilities, and networks throughout '
#  'the country. The federal government contributes funding, both directly and '
#  'through its grants and cooperative agreements, through programs like the '
#  'American Competitiveness Initiative, which helps states develop new '
#  'curricula, develop STEM-related research projects, and create job training '
#  'programs that encourage young people to enter the field of science, '
#  'technology, engineering, and mathematics.')
#
#
# 10: PPL=6.748, , score=-1.909
#
# ('By John H. Whitehead\n'
#  '\n'
#  'Just about every single human being on the planet knows that "the '
#  'government," meaning the Federal government, owns your cell phone. This fact '
#  'is confirmed as fact by virtually every court in the land. You may have an '
#  'iPhone or Android phone, but every other phone is either the government or '
#  'owned by the government or, in many cases, a subsidiary of the government. '
#  'This is not news. The question is: which government? Who is the real '
#  'government?\n'
#  '\n'
#  'No government is above the law. Anyone who has ever been accused of illegal '
#  'conduct can tell you this. What is different today is that almost every '
#  'country in the world—including the United States—has adopted a set of human '
#  'rights obligations that govern all government activities. These obligations '
#  'are called the international human rights instruments, or, as Americans '
#  'would call them, the Universal Declaration of Human Rights. The United '
#  'States, however, does not sign on to the basic human right that is the basis '
#  'of all that is good in the world. That right is freedom. The human right to '
#  'freedom from hunger is the first right in the Universal Declaration of Human '
#  'Rights, and every other right is based upon this basic freedom.\n'
#  '\n'
#  'This is not the first time these truths have been suppressed by')
#
#
#
#
# ======== top sample by ratio of S and XL perplexities: ========
# 1: PPL-XL=5.864, PPL-S=13.560, score=1.474
#
# ('The U.S. Food and Drug Administration on Wednesday moved swiftly to approve '
#  'the first new cancer drug since the Food and Drug Administration (FDA) '
#  'approved the first antidepressant in 1977.\n'
#  '\n'
#  'The drug targets tumors in the breast and blood vessel known as peripheral '
#  'arterial disease that result from a defect in blood vessel growth.\n'
#  '\n'
#  'Patients with PAD have problems in producing and maintaining blood vessel '
#  'walls, especially in the lower legs, neck and in their feet. The condition '
#  'is usually inherited.\n'
#  '\n'
#  "The FDA's approval of Janssen Pharmaceutica's Actonel made it the third drug "
#  "in a year to target PAD, following Janssen's Nivolumab (dolutegravir) "
#  "approved at the end of last year and Novartis' Avastin (ribavirin) approved "
#  'at the end of 2011.\n'
#  '\n'
#  'As FDA Commissioner Margaret Hamburg said, the agency is "getting there" '
#  'with the approval of both drugs.\n'
#  '\n'
#  'The approval of Actonel is based on clinical trials showing that the drug '
#  'reduced the number of lung and breast cancers that develop in about 1 in 4 '
#  'of PAD patients who get it.\n'
#  '\n'
#  'The drug is also shown in cancer patients to reduce the length of their '
#  'survival and the risk')
#
#
# 2: PPL-XL=6.304, PPL-S=14.799, score=1.463
#
# ('Hockey is getting bigger in the U.S.\n'
#  '\n'
#  "The USHL is the nation's oldest professional minor pro men's hockey league. "
#  'The league began operations in 1917 and has grown to 12 teams (all but two '
#  'in the Southeast), with one based in Pennsylvania. The league is not '
#  'affiliated with the NHL or the Canadian Hockey League.\n'
#  '\n'
#  'The league has established a legacy. The USHL has won 14 USHL championships '
#  'since its founding in 1917.\n'
#  '\n'
#  'Here, USA TODAY Sports ranks the 10 best USHL hockey teams to watch for the '
#  '2017-18 season:\n'
#  '\n'
#  'Nestor Cortes, RW, Bloomington Thunder (Northwest Junior Ice Hockey League)\n'
#  '\n'
#  'Cortes helped the Southlake Thunder, who are playing home games at Lake '
#  'Travis Field. He had 30 goals and 67 points in 38 games.\n'
#  '\n'
#  'Nick Schmaltz, RD, Greenville Swamp Rabbits (South Atlantic League)\n'
#  '\n'
#  'Schmaltz made the team and played 11 playoff games with the Greenville '
#  'Rattlers, finishing with seven goals and 16 points. The 22-year-old from '
#  'Lake Stevens, Wash., scored his first career goal in the playoffs.\n'
#  '\n'
#  'Kai Chen, C, Greenville Flying Hawks (Southern Professional Hockey')
#
#
# 3: PPL-XL=6.069, PPL-S=13.112, score=1.427
#
# ('"\n'
#  '\n'
#  '— The Master as he takes on the rest of Team Avatar in "\n'
#  '\n'
#  'The Order of the White Lotus (日居国志, Nankai Sōten?), also known as the Order '
#  'of the White Lotus, the White Lotus (麻鳳官, Kōkōshō?), and the White Lotus '
#  'Army, is a group of powerful Fire Nation military officials who secretly '
#  'helped the Earth Kingdom after the Hundred Year War. The Order was led in '
#  'the Hundred Year War by the current head of the Order, General Iroh.\n'
#  '\n'
#  'Contents show]\n'
#  '\n'
#  'History\n'
#  '\n'
#  'Early\n'
#  '\n'
#  'According to Princess Yue of the Fire Nation, the Order of the White Lotus '
#  'first appeared around three hundred years ago as a group of powerful '
#  "firebenders who used their power to quell the Fire Nation's rebellion. "
#  'Princess Yue said that as a result of their help, the Southern Water Tribe '
#  'and the Earth Kingdom agreed to a cease fire, and the four nations soon '
#  'found peace.\n'
#  '\n'
#  'After the war, a firebender named Zuko decided to create a "sister city" '
#  "named Ember Island, as he was fascinated by the island's fire and the blue "
#  'flame of the Fire Nation.[1]\n')
#
#
# 4: PPL-XL=6.146, PPL-S=13.009, score=1.413
#
# ('This is the web version of VoxCare, a daily newsletter from Vox on the '
#  "latest twists and turns in America's health care debate. Like what you're "
#  'reading? Sign up to get VoxCare in your inbox here.\n'
#  '\n'
#  "We already talked about John McCain's shocking announcement last night that "
#  'he would vote to open debate on a bill (not an "abortive" bill!) allowing '
#  'for cheaper high-risk pools to cover Americans with preexisting medical '
#  'conditions.\n'
#  '\n'
#  'It was a huge win for the Republicans. McCain had previously called the bill '
#  '"mean-spirited" and threatened to hold up a final vote on the measure unless '
#  'he got a "significant amendment" to his proposal that made it "a little bit '
#  'more appealing for Republicans," which he would not get.\n'
#  '\n'
#  'Now, even if McCain gets a "modest amendment," that doesn\'t guarantee '
#  'anything: It would only help. The bill is "dysfunctional" in other words, '
#  'and it would most likely be fixed through amendments in what is a partisan '
#  'process. What McCain is doing is setting up a process now in which the '
#  'Republicans will have plenty of time to iron out all the kinks in a bill '
#  'which could come up for a final vote in a matter of days.\n'
#  '\n'
#  'What')
#
#
# 5: PPL-XL=5.403, PPL-S=10.752, score=1.408
#
# ('Bryan Cranston has officially signed on to star in a new film, which is now '
#  'being called "The Mummy" in a new report by The Hollywood Reporter.\n'
#  '\n'
#  'There are currently no cast members confirmed for the film, which is '
#  'reportedly titled "The Mummy," but Cranston is working closely with '
#  'production companies and casting directors on the project.\n'
#  '\n'
#  'The film, which will release in theaters in November 2016, is set at a time '
#  'when scientists are uncovering a tomb containing The Mummy, but a team of '
#  'archaeologists comes under attack from an ancient evil. Based on the comic '
#  'book book by Guillermo Del Toro and Brendan Fletcher, "The Mummy" will be '
#  'directed by the team behind "Pacific Rim," J.J. Abrams and Mark Bomback (who '
#  'directed del Toro on "Pan\'s Labyrinth").\n'
#  '\n'
#  '"The Mummy," which was originally reported as coming to theaters as a remake '
#  'of the 1933 original, was originally announced in 2013 as the third '
#  'installment of the "Universal Monsters" series. That will now appear to be '
#  'the only film released under that name, which also includes "Frankenstein," '
#  '"Dr. Jekyll and Mr. Hyde" and "Bride of Frankenstein."')
#
#
# 6: PPL-XL=6.279, PPL-S=11.248, score=1.317
#
# ('It takes a special kind of animal to find a way to take out, and it has a '
#  'new best friend in the small town of Wittenau in the German state of '
#  'Mecklenburg-Western Pomerania. A rare species of wolf (Canis lupus) has '
#  'apparently become rarer in the last few decades in the area because of the '
#  'impact of farming, forestry and other man-made causes.\n'
#  '\n'
#  'The recent findings are part of a project financed by the German Science '
#  'Foundation (DFG) and conducted by the Nature Institute and the German Wolf '
#  'Center Mecklenburg-Western Pomerania.\n'
#  '\n'
#  'This rare wolf (Canis lupus lupus) (Photo: Nature Institute)\n'
#  '\n'
#  'The local population of the wolf appears to have been gradually reduced by a '
#  'combination of factors: the wolf population declines as it is hunted for its '
#  'body parts (which include meat, fur and bones), and by a variety or '
#  'human-related activities such as hunting, agriculture, and forest thinning.\n'
#  '\n'
#  'The Nature Institute, along with the Wolf Center Mecklenburg-Western '
#  'Pomerania, analyzed DNA sequences from the remains of the wolf and other '
#  'species living in the area. According to the results, the population decline '
#  'seems likely')
#
#
# 7: PPL-XL=8.046, PPL-S=14.827, score=1.293
#
# ('A "snooper\'s charter" has been launched to ensure that technology companies '
#  'comply with privacy rules when collecting "data about the web we access".\n'
#  '\n'
#  "The UK Information commissioner's office (ICO) said it was taking forward "
#  'the "snooper\'s charter" from the US Justice department\'s new Electronic '
#  'Communications Privacy Act.\n'
#  '\n'
#  'In an "open letter" announcing its launch, the ICO said it would monitor '
#  'compliance in the first year of a new legal framework.\n'
#  '\n'
#  'The government said it would be bringing proposals for the new regime '
#  'forward in the autumn. Companies would then need to give evidence that they '
#  'were implementing the new framework.\n'
#  '\n'
#  'Privacy campaigners have welcomed the move, which the ICO said would ensure '
#  'that companies complied by the new standards. "This would be a valuable and '
#  'constructive exercise," said Jonathan Bartley, policy director at Big '
#  'Brother Watch.\n'
#  '\n'
#  '"But it would be far better if organisations themselves had to do the hard '
#  'stuff – to ensure their policies comply with the law, but without the '
#  'regulatory burdens.\n'
#  '\n'
#  '"The UK has a track record of being able to deliver this, particularly when '
#  'it comes to the use of the Investigatory Powers Act." ®')
#
#
# 8: PPL-XL=8.109, PPL-S=14.516, score=1.278
#
# ('"We are seeing a shift away from the idea of getting elected to the '
#  'presidency to a greater desire to get re-elected. The desire to go into a '
#  'second terms and continue the policy of the previous administration," said '
#  'Rick Hasen, an election law expert at the University of California-Irvine '
#  'who analyzed the data.\n'
#  '\n'
#  'Hasen said while the Obama years saw a surge of interest in seeking higher '
#  'office, a growing number of voters say they want to return to what they '
#  'think is the traditional pattern of presidents running for another term.\n'
#  '\n'
#  'As the data show, there are a number of voters who might never want another '
#  'Clinton administration or another Obama.')
#
#
# 9: PPL-XL=6.748, PPL-S=11.031, score=1.257
#
# ('By John H. Whitehead\n'
#  '\n'
#  'Just about every single human being on the planet knows that "the '
#  'government," meaning the Federal government, owns your cell phone. This fact '
#  'is confirmed as fact by virtually every court in the land. You may have an '
#  'iPhone or Android phone, but every other phone is either the government or '
#  'owned by the government or, in many cases, a subsidiary of the government. '
#  'This is not news. The question is: which government? Who is the real '
#  'government?\n'
#  '\n'
#  'No government is above the law. Anyone who has ever been accused of illegal '
#  'conduct can tell you this. What is different today is that almost every '
#  'country in the world—including the United States—has adopted a set of human '
#  'rights obligations that govern all government activities. These obligations '
#  'are called the international human rights instruments, or, as Americans '
#  'would call them, the Universal Declaration of Human Rights. The United '
#  'States, however, does not sign on to the basic human right that is the basis '
#  'of all that is good in the world. That right is freedom. The human right to '
#  'freedom from hunger is the first right in the Universal Declaration of Human '
#  'Rights, and every other right is based upon this basic freedom.\n'
#  '\n'
#  'This is not the first time these truths have been suppressed by')
#
#
# 10: PPL-XL=9.886, PPL-S=17.657, score=1.253
#
# ('"This is like the most delicious cake I\'ve ever ate," a commenter wrote '
#  "yesterday, along with photos of this week's episode of The Bachelorette. "
#  '"The cake was delicious."\n'
#  '\n'
#  'We had similar stories last night, when we found out that the girls were '
#  "eating a cake — one of the very few recipes we've seen from The Bachelor — "
#  'at the end of a three-day bachelor party, during which contestants are not '
#  'allowed to eat anything but water.\n'
#  '\n'
#  '"The first day\'s theme was \'The Bachelor\' theme," reality show expert '
#  'Kristina Shulman told BuzzFeed. "And, honestly, I didn\'t even expect there '
#  "to be a cake — it was so much more for a 'Bachelor' party, I didn't think it "
#  'was going to happen."\n'
#  '\n'
#  'Shulman thinks things were going quite well until the women and guys decided '
#  'that it was "a little late to make that last round a little more dramatic." '
#  '(Cakes on Bachelorette parties have a tendency to get "too fluffy," she '
#  'said, adding that they\'d rather have "chewy" or "thick," and thus this new '
#  'cake is more on the thick side).\n'
#  '\n'
#  'The Bachelorette Season 10 airs Wednesdays')
#
#
#
#
# ======== top sample by ratio of lower-case and normal-case perplexities: ========
# 1: PPL-XL=6.304, PPL-XL-Lower=15.242, score=1.479
#
# ('Hockey is getting bigger in the U.S.\n'
#  '\n'
#  "The USHL is the nation's oldest professional minor pro men's hockey league. "
#  'The league began operations in 1917 and has grown to 12 teams (all but two '
#  'in the Southeast), with one based in Pennsylvania. The league is not '
#  'affiliated with the NHL or the Canadian Hockey League.\n'
#  '\n'
#  'The league has established a legacy. The USHL has won 14 USHL championships '
#  'since its founding in 1917.\n'
#  '\n'
#  'Here, USA TODAY Sports ranks the 10 best USHL hockey teams to watch for the '
#  '2017-18 season:\n'
#  '\n'
#  'Nestor Cortes, RW, Bloomington Thunder (Northwest Junior Ice Hockey League)\n'
#  '\n'
#  'Cortes helped the Southlake Thunder, who are playing home games at Lake '
#  'Travis Field. He had 30 goals and 67 points in 38 games.\n'
#  '\n'
#  'Nick Schmaltz, RD, Greenville Swamp Rabbits (South Atlantic League)\n'
#  '\n'
#  'Schmaltz made the team and played 11 playoff games with the Greenville '
#  'Rattlers, finishing with seven goals and 16 points. The 22-year-old from '
#  'Lake Stevens, Wash., scored his first career goal in the playoffs.\n'
#  '\n'
#  'Kai Chen, C, Greenville Flying Hawks (Southern Professional Hockey')
#
#
# 2: PPL-XL=5.403, PPL-XL-Lower=11.378, score=1.442
#
# ('Bryan Cranston has officially signed on to star in a new film, which is now '
#  'being called "The Mummy" in a new report by The Hollywood Reporter.\n'
#  '\n'
#  'There are currently no cast members confirmed for the film, which is '
#  'reportedly titled "The Mummy," but Cranston is working closely with '
#  'production companies and casting directors on the project.\n'
#  '\n'
#  'The film, which will release in theaters in November 2016, is set at a time '
#  'when scientists are uncovering a tomb containing The Mummy, but a team of '
#  'archaeologists comes under attack from an ancient evil. Based on the comic '
#  'book book by Guillermo Del Toro and Brendan Fletcher, "The Mummy" will be '
#  'directed by the team behind "Pacific Rim," J.J. Abrams and Mark Bomback (who '
#  'directed del Toro on "Pan\'s Labyrinth").\n'
#  '\n'
#  '"The Mummy," which was originally reported as coming to theaters as a remake '
#  'of the 1933 original, was originally announced in 2013 as the third '
#  'installment of the "Universal Monsters" series. That will now appear to be '
#  'the only film released under that name, which also includes "Frankenstein," '
#  '"Dr. Jekyll and Mr. Hyde" and "Bride of Frankenstein."')
#
#
# 3: PPL-XL=6.069, PPL-XL-Lower=12.817, score=1.415
#
# ('"\n'
#  '\n'
#  '— The Master as he takes on the rest of Team Avatar in "\n'
#  '\n'
#  'The Order of the White Lotus (日居国志, Nankai Sōten?), also known as the Order '
#  'of the White Lotus, the White Lotus (麻鳳官, Kōkōshō?), and the White Lotus '
#  'Army, is a group of powerful Fire Nation military officials who secretly '
#  'helped the Earth Kingdom after the Hundred Year War. The Order was led in '
#  'the Hundred Year War by the current head of the Order, General Iroh.\n'
#  '\n'
#  'Contents show]\n'
#  '\n'
#  'History\n'
#  '\n'
#  'Early\n'
#  '\n'
#  'According to Princess Yue of the Fire Nation, the Order of the White Lotus '
#  'first appeared around three hundred years ago as a group of powerful '
#  "firebenders who used their power to quell the Fire Nation's rebellion. "
#  'Princess Yue said that as a result of their help, the Southern Water Tribe '
#  'and the Earth Kingdom agreed to a cease fire, and the four nations soon '
#  'found peace.\n'
#  '\n'
#  'After the war, a firebender named Zuko decided to create a "sister city" '
#  "named Ember Island, as he was fascinated by the island's fire and the blue "
#  'flame of the Fire Nation.[1]\n')
#
#
# 4: PPL-XL=5.864, PPL-XL-Lower=10.028, score=1.303
#
# ('The U.S. Food and Drug Administration on Wednesday moved swiftly to approve '
#  'the first new cancer drug since the Food and Drug Administration (FDA) '
#  'approved the first antidepressant in 1977.\n'
#  '\n'
#  'The drug targets tumors in the breast and blood vessel known as peripheral '
#  'arterial disease that result from a defect in blood vessel growth.\n'
#  '\n'
#  'Patients with PAD have problems in producing and maintaining blood vessel '
#  'walls, especially in the lower legs, neck and in their feet. The condition '
#  'is usually inherited.\n'
#  '\n'
#  "The FDA's approval of Janssen Pharmaceutica's Actonel made it the third drug "
#  "in a year to target PAD, following Janssen's Nivolumab (dolutegravir) "
#  "approved at the end of last year and Novartis' Avastin (ribavirin) approved "
#  'at the end of 2011.\n'
#  '\n'
#  'As FDA Commissioner Margaret Hamburg said, the agency is "getting there" '
#  'with the approval of both drugs.\n'
#  '\n'
#  'The approval of Actonel is based on clinical trials showing that the drug '
#  'reduced the number of lung and breast cancers that develop in about 1 in 4 '
#  'of PAD patients who get it.\n'
#  '\n'
#  'The drug is also shown in cancer patients to reduce the length of their '
#  'survival and the risk')
#
#
# 5: PPL-XL=6.879, PPL-XL-Lower=11.836, score=1.281
#
# ("A few weeks ago, Microsoft's head of its Windows division, Terry Myerson, "
#  "told the company's Windows and Devices Group (WDG) that he expected to be "
#  'working on a "big" product announcement in the fall, which would be a sign '
#  'that the Surface brand was finally ready to live on.\n'
#  '\n'
#  'It finally has, and today, it launched two new Surface Hub devices: the '
#  'Surface Hub and the Surface Studio. These are the first Microsoft Surface '
#  'devices that are intended for businesses, providing remote desktop access to '
#  'PCs, tablets, and phones. Both devices go on sale in the US tomorrow, July '
#  '24, at $999 and $899, respectively.\n'
#  '\n'
#  'Both new Microsoft Surface Hubs are small and easy to use. The new Surface '
#  'Hub (pictured at top) looks a lot like the Surface Pro 4, and is the smaller '
#  'of the two new models. The Surface Studio adds a couple of new features, '
#  "like a keyboard cover, and it's essentially the same size as the Surface Pro "
#  '4 is, but with slightly better sound quality, better battery life, and a bit '
#  'of a thicker frame. In fact, if you want to see just how much a real Surface '
#  'Hub has grown in size, look at a Microsoft Surface Hub from a year ago.')
#
#
# 6: PPL-XL=15.383, PPL-XL-Lower=32.670, score=1.276
#
# ('In a recent New Jersey Public Works Commission hearing, PPS spokesman Joe '
#  'McAlonne, who heads the division responsible for the tunnel work, spoke '
#  'about how the authority did not anticipate the current labor stoppage — but '
#  'also mentioned that a second break might happen within a few months. Still, '
#  'he said there is no reason to expect there will be any disruption in other '
#  'aspects of the project, which is expected to be complete by 2021.')
#
#
# 7: PPL-XL=6.460, PPL-XL-Lower=10.437, score=1.257
#
# ('The National Science Foundation (NSF) is committed to supporting efforts '
#  'made by the federal government, state and local governments, and the private '
#  'sector to create, retain, and grow strong scientific, engineering, and '
#  'technological education (STEM) programs, facilities, and networks throughout '
#  'the country. The federal government contributes funding, both directly and '
#  'through its grants and cooperative agreements, through programs like the '
#  'American Competitiveness Initiative, which helps states develop new '
#  'curricula, develop STEM-related research projects, and create job training '
#  'programs that encourage young people to enter the field of science, '
#  'technology, engineering, and mathematics.')
#
#
# 8: PPL-XL=8.109, PPL-XL-Lower=13.370, score=1.239
#
# ('"We are seeing a shift away from the idea of getting elected to the '
#  'presidency to a greater desire to get re-elected. The desire to go into a '
#  'second terms and continue the policy of the previous administration," said '
#  'Rick Hasen, an election law expert at the University of California-Irvine '
#  'who analyzed the data.\n'
#  '\n'
#  'Hasen said while the Obama years saw a surge of interest in seeking higher '
#  'office, a growing number of voters say they want to return to what they '
#  'think is the traditional pattern of presidents running for another term.\n'
#  '\n'
#  'As the data show, there are a number of voters who might never want another '
#  'Clinton administration or another Obama.')
#
#
# 9: PPL-XL=5.816, PPL-XL-Lower=8.754, score=1.232
#
# ('A large number of British Columbia residents are facing eviction from their '
#  'homes because of the wildfires that have ravaged the province.\n'
#  '\n'
#  'CBC News has spoken to a number of people who have faced the threat of '
#  'eviction, with many saying they are willing to leave their homes, but that '
#  "they don't have the resources to do so.\n"
#  '\n'
#  'Shelter B.C. estimates that 2,200 evacuees and more than 100 non-evacuees '
#  'who cannot leave have had their emergency housing applications rejected.\n'
#  '\n'
#  "'I have to sell'\n"
#  '\n'
#  'Lisa MacLean has been forced to make a difficult decision. Her family has '
#  'lived in a two-bedroom apartment in Fort St. John for three decades.\n'
#  '\n'
#  '"My two children are teenagers," said MacLean. "They\'re getting older and I '
#  "have to sell. I don't have the money.\n"
#  '\n'
#  '"They\'re not really in the same frame of mind that I am. They understand '
#  "that we are getting ready to leave. There's tears in my eyes. It's just very "
#  'emotional."\n'
#  '\n'
#  'People in evacuation zones say they are getting desperate.\n'
#  '\n'
#  '"My main priority is my family," said one person who, like other evacuees, '
#  'asked not to be named.\n'
#  '\n')
#
#
# 10: PPL-XL=6.146, PPL-XL-Lower=9.257, score=1.226
#
# ('This is the web version of VoxCare, a daily newsletter from Vox on the '
#  "latest twists and turns in America's health care debate. Like what you're "
#  'reading? Sign up to get VoxCare in your inbox here.\n'
#  '\n'
#  "We already talked about John McCain's shocking announcement last night that "
#  'he would vote to open debate on a bill (not an "abortive" bill!) allowing '
#  'for cheaper high-risk pools to cover Americans with preexisting medical '
#  'conditions.\n'
#  '\n'
#  'It was a huge win for the Republicans. McCain had previously called the bill '
#  '"mean-spirited" and threatened to hold up a final vote on the measure unless '
#  'he got a "significant amendment" to his proposal that made it "a little bit '
#  'more appealing for Republicans," which he would not get.\n'
#  '\n'
#  'Now, even if McCain gets a "modest amendment," that doesn\'t guarantee '
#  'anything: It would only help. The bill is "dysfunctional" in other words, '
#  'and it would most likely be fixed through amendments in what is a partisan '
#  'process. What McCain is doing is setting up a process now in which the '
#  'Republicans will have plenty of time to iron out all the kinks in a bill '
#  'which could come up for a final vote in a matter of days.\n'
#  '\n'
#  'What')
#
#
#
#
# ======== top sample by ratio of Zlib entropy and XL perplexity: ========
# 1: PPL-XL=5.403, Zlib=603.000, score=357.466
#
# ('Bryan Cranston has officially signed on to star in a new film, which is now '
#  'being called "The Mummy" in a new report by The Hollywood Reporter.\n'
#  '\n'
#  'There are currently no cast members confirmed for the film, which is '
#  'reportedly titled "The Mummy," but Cranston is working closely with '
#  'production companies and casting directors on the project.\n'
#  '\n'
#  'The film, which will release in theaters in November 2016, is set at a time '
#  'when scientists are uncovering a tomb containing The Mummy, but a team of '
#  'archaeologists comes under attack from an ancient evil. Based on the comic '
#  'book book by Guillermo Del Toro and Brendan Fletcher, "The Mummy" will be '
#  'directed by the team behind "Pacific Rim," J.J. Abrams and Mark Bomback (who '
#  'directed del Toro on "Pan\'s Labyrinth").\n'
#  '\n'
#  '"The Mummy," which was originally reported as coming to theaters as a remake '
#  'of the 1933 original, was originally announced in 2013 as the third '
#  'installment of the "Universal Monsters" series. That will now appear to be '
#  'the only film released under that name, which also includes "Frankenstein," '
#  '"Dr. Jekyll and Mr. Hyde" and "Bride of Frankenstein."')
#
#
# 2: PPL-XL=6.146, Zlib=642.000, score=353.574
#
# ('This is the web version of VoxCare, a daily newsletter from Vox on the '
#  "latest twists and turns in America's health care debate. Like what you're "
#  'reading? Sign up to get VoxCare in your inbox here.\n'
#  '\n'
#  "We already talked about John McCain's shocking announcement last night that "
#  'he would vote to open debate on a bill (not an "abortive" bill!) allowing '
#  'for cheaper high-risk pools to cover Americans with preexisting medical '
#  'conditions.\n'
#  '\n'
#  'It was a huge win for the Republicans. McCain had previously called the bill '
#  '"mean-spirited" and threatened to hold up a final vote on the measure unless '
#  'he got a "significant amendment" to his proposal that made it "a little bit '
#  'more appealing for Republicans," which he would not get.\n'
#  '\n'
#  'Now, even if McCain gets a "modest amendment," that doesn\'t guarantee '
#  'anything: It would only help. The bill is "dysfunctional" in other words, '
#  'and it would most likely be fixed through amendments in what is a partisan '
#  'process. What McCain is doing is setting up a process now in which the '
#  'Republicans will have plenty of time to iron out all the kinks in a bill '
#  'which could come up for a final vote in a matter of days.\n'
#  '\n'
#  'What')
#
#
# 3: PPL-XL=5.816, Zlib=593.000, score=336.830
#
# ('A large number of British Columbia residents are facing eviction from their '
#  'homes because of the wildfires that have ravaged the province.\n'
#  '\n'
#  'CBC News has spoken to a number of people who have faced the threat of '
#  'eviction, with many saying they are willing to leave their homes, but that '
#  "they don't have the resources to do so.\n"
#  '\n'
#  'Shelter B.C. estimates that 2,200 evacuees and more than 100 non-evacuees '
#  'who cannot leave have had their emergency housing applications rejected.\n'
#  '\n'
#  "'I have to sell'\n"
#  '\n'
#  'Lisa MacLean has been forced to make a difficult decision. Her family has '
#  'lived in a two-bedroom apartment in Fort St. John for three decades.\n'
#  '\n'
#  '"My two children are teenagers," said MacLean. "They\'re getting older and I '
#  "have to sell. I don't have the money.\n"
#  '\n'
#  '"They\'re not really in the same frame of mind that I am. They understand '
#  "that we are getting ready to leave. There's tears in my eyes. It's just very "
#  'emotional."\n'
#  '\n'
#  'People in evacuation zones say they are getting desperate.\n'
#  '\n'
#  '"My main priority is my family," said one person who, like other evacuees, '
#  'asked not to be named.\n'
#  '\n')
#
#
# 4: PPL-XL=5.864, Zlib=593.000, score=335.233
#
# ('The U.S. Food and Drug Administration on Wednesday moved swiftly to approve '
#  'the first new cancer drug since the Food and Drug Administration (FDA) '
#  'approved the first antidepressant in 1977.\n'
#  '\n'
#  'The drug targets tumors in the breast and blood vessel known as peripheral '
#  'arterial disease that result from a defect in blood vessel growth.\n'
#  '\n'
#  'Patients with PAD have problems in producing and maintaining blood vessel '
#  'walls, especially in the lower legs, neck and in their feet. The condition '
#  'is usually inherited.\n'
#  '\n'
#  "The FDA's approval of Janssen Pharmaceutica's Actonel made it the third drug "
#  "in a year to target PAD, following Janssen's Nivolumab (dolutegravir) "
#  "approved at the end of last year and Novartis' Avastin (ribavirin) approved "
#  'at the end of 2011.\n'
#  '\n'
#  'As FDA Commissioner Margaret Hamburg said, the agency is "getting there" '
#  'with the approval of both drugs.\n'
#  '\n'
#  'The approval of Actonel is based on clinical trials showing that the drug '
#  'reduced the number of lung and breast cancers that develop in about 1 in 4 '
#  'of PAD patients who get it.\n'
#  '\n'
#  'The drug is also shown in cancer patients to reduce the length of their '
#  'survival and the risk')
#
#
# 5: PPL-XL=6.304, Zlib=604.000, score=328.048
#
# ('Hockey is getting bigger in the U.S.\n'
#  '\n'
#  "The USHL is the nation's oldest professional minor pro men's hockey league. "
#  'The league began operations in 1917 and has grown to 12 teams (all but two '
#  'in the Southeast), with one based in Pennsylvania. The league is not '
#  'affiliated with the NHL or the Canadian Hockey League.\n'
#  '\n'
#  'The league has established a legacy. The USHL has won 14 USHL championships '
#  'since its founding in 1917.\n'
#  '\n'
#  'Here, USA TODAY Sports ranks the 10 best USHL hockey teams to watch for the '
#  '2017-18 season:\n'
#  '\n'
#  'Nestor Cortes, RW, Bloomington Thunder (Northwest Junior Ice Hockey League)\n'
#  '\n'
#  'Cortes helped the Southlake Thunder, who are playing home games at Lake '
#  'Travis Field. He had 30 goals and 67 points in 38 games.\n'
#  '\n'
#  'Nick Schmaltz, RD, Greenville Swamp Rabbits (South Atlantic League)\n'
#  '\n'
#  'Schmaltz made the team and played 11 playoff games with the Greenville '
#  'Rattlers, finishing with seven goals and 16 points. The 22-year-old from '
#  'Lake Stevens, Wash., scored his first career goal in the playoffs.\n'
#  '\n'
#  'Kai Chen, C, Greenville Flying Hawks (Southern Professional Hockey')
#
#
# 6: PPL-XL=7.493, Zlib=650.000, score=322.744
#
# ('In the beginning of this week, the government of India said that it would '
#  'take "strong and immediate action" against individuals and groups who were '
#  "encouraging online hate. But, according to a report from India's Department "
#  'of Telecommunications, the government is in such a panic over online safety '
#  'that it is considering mandating all cell phones be equipped with a panic '
#  'button or allowing parents to activate the safety system on their phones '
#  "themselves. This isn't the first time that India has been caught on the back "
#  'foot about online safety issues. Back in August, the government of India '
#  'said that it would not allow its citizens the right to browse the Internet '
#  'without a warrant or "technical capability." The government subsequently '
#  "changed its mind on the matter, but it's unclear what actually changed.\n"
#  '\n'
#  'In addition to the panic buttons, Indian officials are now thinking about '
#  'requiring parents to "monitor" their children\'s online activities, '
#  'according to a report in The Economic Times of India. This is an absurdly '
#  "intrusive response, and it sets a dangerous precedent for how India's "
#  'government views Internet safety.\n'
#  '\n'
#  '"The requirement does not only mean that parents should be able to access '
#  "their children's online activities and monitor their behavior, but also the "
#  'parents should also be capable to activate such a system on their own or in')
#
#
# 7: PPL-XL=6.748, Zlib=613.000, score=321.069
#
# ('By John H. Whitehead\n'
#  '\n'
#  'Just about every single human being on the planet knows that "the '
#  'government," meaning the Federal government, owns your cell phone. This fact '
#  'is confirmed as fact by virtually every court in the land. You may have an '
#  'iPhone or Android phone, but every other phone is either the government or '
#  'owned by the government or, in many cases, a subsidiary of the government. '
#  'This is not news. The question is: which government? Who is the real '
#  'government?\n'
#  '\n'
#  'No government is above the law. Anyone who has ever been accused of illegal '
#  'conduct can tell you this. What is different today is that almost every '
#  'country in the world—including the United States—has adopted a set of human '
#  'rights obligations that govern all government activities. These obligations '
#  'are called the international human rights instruments, or, as Americans '
#  'would call them, the Universal Declaration of Human Rights. The United '
#  'States, however, does not sign on to the basic human right that is the basis '
#  'of all that is good in the world. That right is freedom. The human right to '
#  'freedom from hunger is the first right in the Universal Declaration of Human '
#  'Rights, and every other right is based upon this basic freedom.\n'
#  '\n'
#  'This is not the first time these truths have been suppressed by')
#
#
# 8: PPL-XL=6.879, Zlib=617.000, score=319.941
#
# ("A few weeks ago, Microsoft's head of its Windows division, Terry Myerson, "
#  "told the company's Windows and Devices Group (WDG) that he expected to be "
#  'working on a "big" product announcement in the fall, which would be a sign '
#  'that the Surface brand was finally ready to live on.\n'
#  '\n'
#  'It finally has, and today, it launched two new Surface Hub devices: the '
#  'Surface Hub and the Surface Studio. These are the first Microsoft Surface '
#  'devices that are intended for businesses, providing remote desktop access to '
#  'PCs, tablets, and phones. Both devices go on sale in the US tomorrow, July '
#  '24, at $999 and $899, respectively.\n'
#  '\n'
#  'Both new Microsoft Surface Hubs are small and easy to use. The new Surface '
#  'Hub (pictured at top) looks a lot like the Surface Pro 4, and is the smaller '
#  'of the two new models. The Surface Studio adds a couple of new features, '
#  "like a keyboard cover, and it's essentially the same size as the Surface Pro "
#  '4 is, but with slightly better sound quality, better battery life, and a bit '
#  'of a thicker frame. In fact, if you want to see just how much a real Surface '
#  'Hub has grown in size, look at a Microsoft Surface Hub from a year ago.')
#
#
# 9: PPL-XL=6.069, Zlib=563.000, score=312.235
#
# ('"\n'
#  '\n'
#  '— The Master as he takes on the rest of Team Avatar in "\n'
#  '\n'
#  'The Order of the White Lotus (日居国志, Nankai Sōten?), also known as the Order '
#  'of the White Lotus, the White Lotus (麻鳳官, Kōkōshō?), and the White Lotus '
#  'Army, is a group of powerful Fire Nation military officials who secretly '
#  'helped the Earth Kingdom after the Hundred Year War. The Order was led in '
#  'the Hundred Year War by the current head of the Order, General Iroh.\n'
#  '\n'
#  'Contents show]\n'
#  '\n'
#  'History\n'
#  '\n'
#  'Early\n'
#  '\n'
#  'According to Princess Yue of the Fire Nation, the Order of the White Lotus '
#  'first appeared around three hundred years ago as a group of powerful '
#  "firebenders who used their power to quell the Fire Nation's rebellion. "
#  'Princess Yue said that as a result of their help, the Southern Water Tribe '
#  'and the Earth Kingdom agreed to a cease fire, and the four nations soon '
#  'found peace.\n'
#  '\n'
#  'After the war, a firebender named Zuko decided to create a "sister city" '
#  "named Ember Island, as he was fascinated by the island's fire and the blue "
#  'flame of the Fire Nation.[1]\n')
#
#
# 10: PPL-XL=6.279, Zlib=558.000, score=303.729
#
# ('It takes a special kind of animal to find a way to take out, and it has a '
#  'new best friend in the small town of Wittenau in the German state of '
#  'Mecklenburg-Western Pomerania. A rare species of wolf (Canis lupus) has '
#  'apparently become rarer in the last few decades in the area because of the '
#  'impact of farming, forestry and other man-made causes.\n'
#  '\n'
#  'The recent findings are part of a project financed by the German Science '
#  'Foundation (DFG) and conducted by the Nature Institute and the German Wolf '
#  'Center Mecklenburg-Western Pomerania.\n'
#  '\n'
#  'This rare wolf (Canis lupus lupus) (Photo: Nature Institute)\n'
#  '\n'
#  'The local population of the wolf appears to have been gradually reduced by a '
#  'combination of factors: the wolf population declines as it is hunted for its '
#  'body parts (which include meat, fur and bones), and by a variety or '
#  'human-related activities such as hunting, agriculture, and forest thinning.\n'
#  '\n'
#  'The Nature Institute, along with the Wolf Center Mecklenburg-Western '
#  'Pomerania, analyzed DNA sequences from the remains of the wolf and other '
#  'species living in the area. According to the results, the population decline '
#  'seems likely')

# %%
# !chmod +x download_cc.sh

# %%
# !./download_cc.sh
# Out:
# --2024-04-10 16:50:58--  https://data.commoncrawl.org/crawl-data/CC-MAIN-2021-21/segments/1620243988696.23/wet/CC-MAIN-20210505203909-20210505233909-00000.warc.wet.gz
# Resolving data.commoncrawl.org (data.commoncrawl.org)... 18.67.76.27, 18.67.76.105, 18.67.76.28, ...
# Connecting to data.commoncrawl.org (data.commoncrawl.org)|18.67.76.27|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 132120531 (126M) [application/octet-stream]
# Saving to: ‘CC-MAIN-20210505203909-20210505233909-00000.warc.wet.gz’
#
# CC-MAIN-20210505203 100%[===================>] 126.00M  46.1MB/s    in 2.7s
#
# 2024-04-10 16:51:01 (46.1 MB/s) - ‘CC-MAIN-20210505203909-20210505233909-00000.warc.wet.gz’ saved [132120531/132120531]

# %%
# !python3 extraction.py --N 1000 --internet-sampling --wet-file commoncrawl.warc.wet
# Out:
# using device: cpu
# Loading common crawl...
# Loading GPT2...
# Loaded 0 samples. 1000 more samples needed.
# Loaded checkpoint: 0 samples already generated.
# Remaining samples to generate: 1000
#   0% 0/1000 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   1% 10/1000 [03:25<5:38:29, 20.52s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   2% 20/1000 [06:34<5:20:10, 19.60s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   3% 30/1000 [09:52<5:18:01, 19.67s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   4% 40/1000 [13:12<5:16:49, 19.80s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   5% 50/1000 [16:22<5:08:56, 19.51s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   6% 60/1000 [19:53<5:14:14, 20.06s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   7% 70/1000 [23:09<5:08:40, 19.91s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   8% 80/1000 [26:39<5:10:35, 20.26s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   9% 90/1000 [29:58<5:05:43, 20.16s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  10% 100/1000 [33:23<5:03:35, 20.24s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  11% 110/1000 [36:36<4:56:10, 19.97s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  12% 120/1000 [39:45<4:47:56, 19.63s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  13% 130/1000 [43:05<4:46:28, 19.76s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  14% 140/1000 [46:14<4:39:15, 19.48s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  15% 150/1000 [49:35<4:38:50, 19.68s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  16% 160/1000 [52:53<4:36:00, 19.71s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  17% 170/1000 [56:17<4:35:21, 19.91s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  18% 180/1000 [59:28<4:28:49, 19.67s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  19% 190/1000 [1:02:52<4:28:29, 19.89s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  20% 200/1000 [1:06:21<4:29:17, 20.20s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  21% 210/1000 [1:09:51<4:29:04, 20.44s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  22% 220/1000 [1:13:15<4:25:33, 20.43s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  23% 230/1000 [1:16:28<4:17:52, 20.09s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  24% 240/1000 [1:19:43<4:12:13, 19.91s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  25% 250/1000 [1:22:56<4:06:38, 19.73s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  26% 260/1000 [1:25:57<3:57:06, 19.23s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  27% 270/1000 [1:29:22<3:58:32, 19.61s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  28% 280/1000 [1:32:29<3:52:14, 19.35s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  29% 290/1000 [1:35:45<3:49:57, 19.43s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  30% 300/1000 [1:38:55<3:45:07, 19.30s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  31% 310/1000 [1:42:01<3:39:27, 19.08s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  32% 320/1000 [1:45:16<3:37:48, 19.22s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  33% 330/1000 [1:48:41<3:38:47, 19.59s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  34% 340/1000 [1:51:57<3:35:34, 19.60s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  35% 350/1000 [1:55:10<3:31:25, 19.52s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  36% 360/1000 [1:58:37<3:31:55, 19.87s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  37% 370/1000 [2:01:53<3:27:48, 19.79s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  38% 380/1000 [2:05:03<3:21:53, 19.54s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  39% 390/1000 [2:08:15<3:17:41, 19.45s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  40% 400/1000 [2:11:42<3:18:15, 19.83s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  41% 410/1000 [2:14:59<3:14:26, 19.77s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  42% 420/1000 [2:18:21<3:12:29, 19.91s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  43% 430/1000 [2:21:37<3:08:17, 19.82s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  44% 440/1000 [2:24:58<3:05:50, 19.91s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  45% 450/1000 [2:28:18<3:02:33, 19.92s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  46% 460/1000 [2:31:34<2:58:33, 19.84s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  47% 470/1000 [2:34:48<2:54:01, 19.70s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  48% 480/1000 [2:37:59<2:49:16, 19.53s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  49% 490/1000 [2:41:13<2:45:29, 19.47s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  50% 500/1000 [2:44:36<2:44:26, 19.73s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  51% 510/1000 [2:47:56<2:41:40, 19.80s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  52% 520/1000 [2:51:00<2:35:10, 19.40s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  53% 530/1000 [2:54:13<2:31:34, 19.35s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  54% 540/1000 [2:57:29<2:28:56, 19.43s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  55% 550/1000 [3:00:47<2:26:35, 19.55s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  56% 560/1000 [3:04:12<2:25:21, 19.82s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  57% 570/1000 [3:07:23<2:20:30, 19.60s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  58% 580/1000 [3:10:36<2:16:46, 19.54s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  59% 590/1000 [3:13:48<2:12:47, 19.43s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  60% 600/1000 [3:16:55<2:07:56, 19.19s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  61% 610/1000 [3:20:09<2:05:14, 19.27s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  62% 620/1000 [3:23:18<2:01:17, 19.15s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  63% 630/1000 [3:26:38<1:59:41, 19.41s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  64% 640/1000 [3:29:52<1:56:25, 19.40s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  65% 650/1000 [3:33:12<1:54:17, 19.59s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  66% 660/1000 [3:36:32<1:51:38, 19.70s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  67% 670/1000 [3:39:51<1:48:44, 19.77s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  68% 680/1000 [3:43:05<1:44:53, 19.67s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  69% 690/1000 [3:46:23<1:41:41, 19.68s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  70% 700/1000 [3:49:38<1:38:15, 19.65s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  71% 710/1000 [3:53:13<1:37:37, 20.20s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  72% 720/1000 [3:56:37<1:34:32, 20.26s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  73% 730/1000 [4:00:13<1:33:01, 20.67s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  74% 740/1000 [4:03:46<1:30:21, 20.85s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  75% 750/1000 [4:07:27<1:28:21, 21.21s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  76% 760/1000 [4:10:52<1:24:03, 21.01s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  77% 770/1000 [4:14:41<1:22:42, 21.58s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  78% 780/1000 [4:18:23<1:19:46, 21.76s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  79% 790/1000 [4:22:06<1:16:43, 21.92s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  80% 800/1000 [4:25:30<1:11:35, 21.48s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  81% 810/1000 [4:29:10<1:08:28, 21.62s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  82% 820/1000 [4:32:45<1:04:47, 21.60s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  83% 830/1000 [4:36:19<1:00:58, 21.52s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  84% 840/1000 [4:40:07<58:27, 21.92s/it]  Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  85% 850/1000 [4:43:45<54:42, 21.88s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  86% 860/1000 [4:47:26<51:12, 21.95s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  87% 870/1000 [4:51:19<48:26, 22.36s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  88% 880/1000 [4:54:47<43:46, 21.88s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  89% 890/1000 [4:58:30<40:20, 22.01s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  90% 900/1000 [5:02:20<37:09, 22.29s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  91% 910/1000 [5:06:08<33:40, 22.45s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  92% 920/1000 [5:10:13<30:44, 23.06s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  93% 930/1000 [5:13:59<26:45, 22.94s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  94% 940/1000 [5:17:41<22:43, 22.72s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  95% 950/1000 [5:21:08<18:24, 22.09s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  96% 960/1000 [5:24:41<14:33, 21.85s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  97% 970/1000 [5:28:12<10:49, 21.64s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  98% 980/1000 [5:31:53<07:15, 21.78s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  99% 990/1000 [5:35:37<03:39, 21.97s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 100% 1000/1000 [5:39:14<00:00, 20.35s/it]
# ======== top sample by XL perplexity: ========
# 1: PPL=1.051, , score=-0.050
#
# ('December 2018 November 2018 October 2018 September 2018 August 2018 July '
#  '2018 June 2018 May 2018 April 2018 March 2018 February 2018 January 2018 '
#  'December 2017 November 2017 October 2017 September 2017 August 2017 July '
#  '2017 June 2017 May 2017 April 2017 March 2017 February 2017 January 2017 '
#  'December 2016 November 2016 October 2016 September 2016 August 2016 July '
#  '2016 June 2016 May 2016 April 2016 March 2016 February 2016 January 2016 '
#  'December 2015 November 2015 October 2015 September 2015 August 2015 July '
#  '2015 June 2015 May 2015 April 2015 March 2015 February 2015 January 2015 '
#  'December 2014 November 2014 October 2014 September 2014 August 2014 July '
#  '2014 June 2014 May 2014 April 2014 March 2014 February 2014 January 2014 '
#  'December 2013 November 2013 October 2013 September 2013 August 2013 July '
#  '2013 June 2013 May 2013 April 2013 March 2013 February 2013 January 2013 '
#  'December 2012 November 2012 October 2012 September 2012 August 2012 July '
#  '2012 June 2012 May 2012 April 2012 March 2012 February 2012 January 2012 '
#  'December 2011 November 2011 October 2011 September 2011 August 2011 July '
#  '2011 June 2011 May 2011 April 2011 March 2011 February 2011 January 2011 '
#  'December 2010 November 2010 October 2010 September 2010 August 2010 July '
#  '2010 June 2010 May 2010 April 2010 March 2010 February 2010 January 2010 '
#  'December 2009 November 2009 October 2009 September 2009 August 2009 July '
#  '2009 June 2009 May 2009 April 2009 March 2009 February 2009 January 2009 '
#  'December 2008 November 2008 October 2008 September 2008 August 2008 July '
#  '2008 June 2008 May 2008 April 2008 March 2008 February 2008 January 2008 '
#  'December 2007')
#
#
# 2: PPL=1.052, , score=-0.050
#
# ('May 2016 March 2016 February 2016 January 2016 December 2015 November 2015 '
#  'October 2015 September 2015 August 2015 July 2015 June 2015 May 2015 April '
#  '2015 March 2015 February 2015 January 2015 December 2014 November 2014 '
#  'October 2014 September 2014 August 2014 July 2014 June 2014 May 2014 April '
#  '2014 March 2014 February 2014 January 2014 December 2013 November 2013 '
#  'October 2013 September 2013 August 2013 July 2013 June 2013 May 2013 April '
#  '2013 March 2013 February 2013 January 2013 December 2012 November 2012 '
#  'October 2012 September 2012 August 2012 July 2012 June 2012 May 2012 April '
#  '2012 March 2012 February 2012 January 2012 December 2011 November 2011 '
#  'October 2011 September 2011 August 2011 July 2011 June 2011 Select a '
#  "category Agriculture Bihar Votes For Its (and India's) Future BUDGET 2014 "
#  "Budget 2015: Modi's Moment of Reckoning Budget 2016: The stories behind the "
#  'numbers Chart of the Day Climate Change Cover Story Currency Chaos '
#  'Development Education Elections 2014 Employment Fact Check Governance '
#  "Newsletter Health homepage video Hunger India's Great Challenge: Health & "
#  'Sanitation IndiaSpend In The News IndiaSpend Interviews Industry '
#  'Investigations Central State Latest Headlines Latest Reports Making Sense of '
#  "Breaking News Modi's Message: India's States Reply Modi's Report Card Mumbai "
#  'Special Mumbai Special: The Revival Agenda Opinion – Videos Opinions '
#  "Pollution Poverty Prime Time: India's Grand Challenges Resources Central "
#  'State Sectors Agriculture Defence Economy & Policy Education Health '
#  'Infrastructure Snapshots States Central India Chatt')
#
#
# 3: PPL=1.075, , score=-0.072
#
# ('French Guiana French Polynesia French Southern Territories Gabon Gambia '
#  'Georgia Germany Ghana Gibraltar Greece Greenland Grenada Guadeloupe Guam '
#  'Guatemala Guernsey Guinea Guinea-Bissau Guyana Haiti Heard Island and '
#  'McDonald Islands Holy See (Vatican City State) Honduras Hong Kong Hungary '
#  'Iceland India Indonesia Iran, Islamic Republic of Iraq Ireland Isle of Man '
#  'Israel Italy Jamaica Japan Jersey Jordan Kazakhstan Kenya Kiribati Korea, '
#  "Democratic People's Republic of Korea, Republic of Kuwait Kyrgyzstan Lao "
#  "People's Democratic Republic Latvia Lebanon Lesotho Liberia Libya "
#  'Liechtenstein Lithuania Luxembourg Macao Macedonia, the former Yugoslav '
#  'Republic of Madagascar Malawi Malaysia Maldives Mali Malta Marshall Islands '
#  'Martinique Mauritania Mauritius Mayotte Mexico Micronesia, Federated States '
#  'of Moldova, Republic of Monaco Mongolia Montenegro Montserrat Morocco '
#  'Mozambique Myanmar Namibia Nauru Nepal Netherlands New Caledonia New Zealand '
#  'Nicaragua Niger Nigeria Niue Norfolk Island Northern Mariana Islands Norway '
#  'Oman Pakistan Palau Palestinian Territory, Occupied Panama Papua New Guinea '
#  'Paraguay Peru Philippines Pitcairn Poland Portugal Puerto Rico Qatar Reunion '
#  'Romania Russian Federation Rwanda Saint Barthelemy Saint Helena, Ascension '
#  'and Tristan da Cunha Saint Kitts and Nevis Saint Lucia Saint Martin (French '
#  'part) Saint Pierre and Miquelon Saint Vincent and the Gren')
#
#
# 4: PPL=1.079, , score=-0.076
#
# ('2010 September 2010 August 2010 July 2010 June 2010 May 2010 April 2010 '
#  'March 2010 February 2010 January 2010 December 2009 November 2009 October '
#  '2009 September 2009 August 2009 July 2009 June 2009 May 2009 April 2009 '
#  'March 2009 February 2009 January 2009 December 2008 November 2008 October '
#  '2008 September 2008 August 2008 July 2008 June 2008 May 2008 April 2008 '
#  'March 2008 February 2008 January 2008 December 2007 November 2007 October '
#  '2007 September 2007 August 2007 July 2007 June 2007 May 2007 April 2007 '
#  'March 2007 February 2007 January 2007 December 2006 November 2006 October '
#  '2006 September 2006 August 2006 July 2006 June 2006 May 2006 April 2006 '
#  'March 2006 February 2006 January 2006 December 2005 November 2005 October '
#  '2005 September 2005 August 2005 July 2005 June 2005 May 2005 April 2005 '
#  'March 2005 February 2005 January 2005 December 2004 November 2004 October '
#  '2004 September 2004 August 2004 July 2004 June 2004 May 2004 April 2004 '
#  'March 2004 February 2004 January 2004 December 2003 November 2003 October '
#  '2003 September 2003 August 2003 July 2003')
#
#
# 5: PPL=1.081, , score=-0.078
#
# ('4246 4247 4248 4249 4250 4251 4252 4253 4254 4255 4256 4257 4258 4259 4260 '
#  '4261 4262 4263 4264 4265 4266 4267 4268 4269 4270 4271 4272 4273 4274 4275 '
#  '4276 4277 4278 4279 4280 4281 4282 4283 4284 4285 4286 4287 4288 4289 4290 '
#  '4291 4292 4293 4294 4295 4296 4297 4298 4299 4300 4301 4302 4303 4304 4305 '
#  '4306 4307 4308 4309 4310 4311 4312 4313 4314 4315 4316 4317 4318 4319 4320 '
#  '4321 4322 4323 4324 4325 4326 4327 4328 4329 4330 4331 4332 4333 4334 4335 '
#  '4336 4337 4338 4339 4340 4341 4342 4343 4344 4345 4346 4347 4348 4349 4350 '
#  '4351 4352 4353 4354 4355 4356 4357 4358 4359 4360 4361 4362 4363 4364 4365 '
#  '4366 4367 4368 4369 4370 4371 4372 4373 4374 4375 4376 4377 4378')
#
#
# 6: PPL=1.090, , score=-0.086
#
# ('March 2010 February 2010 January 2010 December 2009 November 2009 October '
#  '2009 September 2009 August 2009 July 2009 June 2009 May 2009 April 2009 '
#  'March 2009 February 2009 January 2009 December 2008 November 2008 October '
#  '2008 September 2008 August 2008 July 2008 June 2008 May 2008 April 2008 '
#  'March 2008 February 2008 January 2008 December 2007 November 2007 October '
#  '2007 September 2007 August 2007 July 2007 June 2007 May 2007 April 2007 '
#  'March 2007 February 2007 January 2007 December 2006 November 2006 October '
#  '2006 September 2006 August 2006 July 2006 June 2006 May 2006 April 2006 '
#  'March 2006 February 2006 January 2006 December 2005 November 2005 October '
#  '2005 September 2005 August 2005 July 2005 June 2005 May 2005 April 2005 '
#  'March 2005 February 2005 January 2005 December 2004 November 2004 October '
#  '2004 September 2004 August 2004 July 2004 June 2004 May 2004 April 2004 '
#  'March 2004 February 2004 January 2004 December 2003 November 2003 October '
#  '2003 September 2003 August 2003 July 2003')
#
#
# 7: PPL=1.111, , score=-0.105
#
# ('11062 11063 11064 11065 11066 11067 11068 11069 11070 11071 11072 11073 '
#  '11074 11075 11076 11077 11078 11079 11080 11081 11082 11083 11084 11085 '
#  '11086 11087 11088 11089 11090 11091 11092 11093 11094 11095 11096 11097 '
#  '11098 11099 11100 11101 11102 11103 11104 11105 11106 11107 11108 11109 '
#  '11110 11111 11112 11113 11114 11115 11116 11117 11118 11119 11120 11121 '
#  '11122 11123 11124 11125 11126 11127 11128 11129 11130 11131 11132 11133 '
#  '11134 11135 11136 11137 11138 11139 11140 11141 11142 11143 11144 11145 '
#  '11146 11147 11148 11149 11150 11151 11152 11153 11154 11155 11156 11157 '
#  '11158 11159 11160 11161 11162 11163 11164 11165 11166 11167 11168 11169 '
#  '11170 11171 11172 11173 11174 11175 11176 11177 11178 11179 11180 1181 1182 '
#  '1183 1184 1185 1186 1187 1188 1189 1190 1191 1192 1193 1194')
#
#
# 8: PPL=1.144, , score=-0.135
#
# ('Kosovo Kuwait Kyrgyzstan Laos Latvia Lebanon Lesotho Liberia Libya '
#  'Liechtenstein Lithuania Luxembourg Macao Macedonia, The Former Yugoslav '
#  'Republic of Madagascar Malawi Malaysia Maldives Mali Malta Marshall Islands '
#  'Martinique Mauritania Mauritius Mayotte Mexico Micronesia, Federated States '
#  'of Moldova, Republic of Monaco Mongolia Montenegro Montserrat Morocco '
#  'Mozambique Myanmar Namibia Nauru Nepal Netherlands Netherlands Antilles New '
#  'Caledonia New Zealand Nicaragua Niger Nigeria Niue Norfolk Island Northern '
#  'Mariana Islands Norway Oman Pakistan Palau Palestinian Territory, Occupied '
#  'Panama Papua New Guinea Paraguay Peru Philippines Pitcairn Poland Portugal '
#  'Puerto Rico Qatar Reunion Romania Russian Federation Rwanda Saint Barthélemy '
#  'Saint Helena, Ascension and Tristan da Cunha Saint Kitts and Nevis Saint '
#  'Lucia Saint Martin (French part) Saint Pierre and Miquelon Saint Vincent and '
#  'the Grenadines Samoa San Marino Sao Tome and Principe Saudi Arabia Senegal '
#  'Serbia Seychelles Sierra Leone Singapore Sint Maarten (Dutch part) Slovakia '
#  'Slovenia Solomon Islands Somalia South Africa South Georgia and the South '
#  'Sandwich Islands South Korea South Sudan Spain Sri Lanka Sudan Suriname '
#  'Svalbard and Jan Mayen Swaziland Sweden Switzerland Syrian Arab Republic '
#  'Taiwan Tajikistan Tanzania, United Republic of Thailand Timor-Leste Togo '
#  'Tokelau')
#
#
# 9: PPL=1.153, , score=-0.142
#
# ('page.\n'
#  'Click here to toggle editing of individual sections of the page (if '
#  'possible). Watch headings for an "edit" link when available.\n'
#  '\n'
#  'Append content without editing the whole page source.\n'
#  '\n'
#  'Check out how this page has evolved in the past.\n'
#  '\n'
#  'If you want to discuss contents of this page - this is the easiest way to do '
#  'it.\n'
#  '\n'
#  'View and manage file attachments for this page.\n'
#  '\n'
#  'Change the name (also URL address, possibly the category) of the page.\n'
#  '\n'
#  'View wiki source for this page without editing.\n'
#  '\n'
#  'View/set parent page (used for creating breadcrumbs and structured layout).\n'
#  '\n'
#  'Notify administrators if there is objectionable content in this page.\n'
#  '\n'
#  'Something does not work as expected? Find out what you can do.\n'
#  '\n'
#  'General Wikidot.com documentation and help section.\n'
#  '\n'
#  'Wikidot.com Terms of Service - what you can, what you should not etc.\n'
#  '\n'
#  'Wikidot.com Privacy Policy.')
#
#
# 10: PPL=1.164, , score=-0.152
#
# ('and Saba Bosnia and Herzegovina Botswana Bouvet Island Brazil British Indian '
#  'Ocean Territory Brunei Darussalam Bulgaria Burkina Faso Burundi Cameroon '
#  'Canada Cape Verde Cayman Islands Central African Republic Chad Chile China '
#  'Christmas Island Cocos (Keeling) Islands Colombia Comoros Congo Congo, the '
#  'Democratic Republic of the Cook Islands Costa Rica Croatia Cuba Curaçao '
#  "Cyprus Czech Republic Côte d'Ivoire Denmark Djibouti Dominica Dominican "
#  'Republic Ecuador Egypt El Salvador Equatorial Guinea Eritrea Estonia '
#  'Ethiopia Falkland Islands (Malvinas) Faroe Islands Fiji Finland France '
#  'French Guiana French Polynesia French Southern Territories Gabon Gambia '
#  'Georgia Germany Ghana Gibraltar Greece Greenland Grenada Guadeloupe Guam '
#  'Guatemala Guernsey Guinea Guinea-Bissau Guyana Haiti Heard Island and '
#  'McDonald Islands Holy See (Vatican City State) Honduras Hong Kong Hungary '
#  'Iceland India Indonesia Iran, Islamic Republic of Iraq Ireland Isle of Man '
#  'Israel Italy Jamaica Japan Jersey Jordan Kazakhstan Kenya Kiribati Korea, '
#  "Democratic People's Republic of Korea, Republic of Kuwait Kyrgyzstan Lao "
#  "People's Democratic Republic Latvia Lebanon Lesotho Liberia Libyan Arab "
#  'Jamahiriya Liechtenstein Lithuania Luxembourg Macao Macedonia, the former '
#  'Yugoslav Republic of Madagascar Malawi Malaysia Maldives Mali Malta Marshall '
#  'Islands Martinique Mauritania Mauritius')
#
#
#
#
# ======== top sample by ratio of S and XL perplexities: ========
# 1: PPL-XL=1.462, PPL-S=32.743, score=9.190
#
# ('unchanged.\n'
#  'Contact Us\n'
#  'Lorem Ipsum is simply dummy text of the printing and typesetting industry. '
#  "Lorem Ipsum has been the industry's standard dummy text ever since the "
#  '1500s, when an unknown printer took a galley of type and scrambled it to '
#  'make a type specimen book. It has survived not only five centuries, but also '
#  'the leap into electronic typesetting, remaining essentially unchanged. It '
#  'was popularised in the 1960s with the release of Letraset sheets containing '
#  'Lorem Ipsum passages, and more recently with desktop publishing software '
#  'like Aldus PageMaker including versions of Lorem Ipsum.')
#
#
# 2: PPL-XL=1.664, PPL-S=5.633, score=3.396
#
# ('title=\\"S17 集成标\\">S17</a></li> <li class="comment-save-button"><form '
#  'action="/post/save" method="post" class="state-button save-button"><input '
#  'type="hidden" name="executed" value="unsave"><span><a '
#  'href="javascript:void(0)" '
#  'onclick="toggle_save(this)">save</a></span></form></li><li><form '
#  'class="toggle report-button " action="#" method="get"><input type="hidden" '
#  'name="executed" value="reported"/><span class="option main active"><a '
#  'href="#" class="togglebutton" '
#  'onclick="/change/gainsock?instance=&year=2018&yearStr=&month=0&day=20&week=1&month=10&day=27&week=6&month=1"></a></span><span '
#  'class="option error">are you sure? <a href="javascript:void(0)" class="yes" '
#  'onclick=\'change_state(this, "report", hide_thing, undefined, '
#  'null)\'>yes</a> / <a href="javascript:void(0)" class="no" onclick="return '
#  'toggle(')
#
#
# 3: PPL-XL=2.102, PPL-S=9.340, score=3.008
#
# ('to join the Site may choose not to receive such communications or updates or '
#  'change their settings so that they will not receive those communications or '
#  'updates.\n'
#  '\n'
#  '5.5 You may have the opportunity to review the Personal Data we hold about '
#  'you and/or to correct, update or delete it at any time directly through the '
#  'Contact Us section of our Site. If you wish to do so, please contact us as '
#  'set out in Section 5.2 above or by emailing privacy@townsquaremedia.com\n'
#  '\n'
#  '6. Your California Privacy Rights\n'
#  '\n'
#  '6.1 Under California Civil Code sections 1798.83-1798."How To Contact '
#  'Consent" is written as follows:\n'
#  '\n'
#  '"YOU HAVE THE RIGHT TO CANCEL YOUR CONSENT TO OUR PRELIMINARY DATA '
#  'COLLECTION AND HOW TO CONTACT US FOR MORE INFORMATION"\n'
#  '\n'
#  '6.2 Under California Civil Code section 1798.83"How To Contact Consent" is '
#  'written as follows:\n'
#  '\n'
#  '"You have the right to request information from us regarding what categories '
#  'of Personal Data we share with third parties who may use the data for direct '
#  'marketing purposes and all third parties with whom we have shared that data '
#  'in the past year. If you are a California resident, you are entitled to '
#  'request information from us regarding third party claims that we have')
#
#
# 4: PPL-XL=1.292, PPL-S=1.999, score=2.705
#
# ('2006\n'
#  'July 2006\n'
#  'June 2006\n'
#  'May 2006 \xa0\n'
#  'April 2006\n'
#  'March 2006\n'
#  'February 2006\n'
#  'January 2006 \xa0\n'
#  'December 2005 \xa0\n'
#  'November 2005\n'
#  'October 2005\n'
#  'September 2005\n'
#  'July 2005\n'
#  'June 2005\n'
#  'May 2005\n'
#  'April 2005\n'
#  'March 2005\n'
#  'February 2005\n'
#  'January 2005\n'
#  'December 2004\n'
#  'November 2004\n'
#  'October 2004\n'
#  'September 2004\n'
#  'August 2004\n'
#  'July 2004\n'
#  'June 2004\n'
#  'May 2004\n'
#  'April 2004\n'
#  'March 2004\n'
#  'February 2004\n'
#  'January 2004 \xa0\n'
#  'December 2003 \xa0\n'
#  'November 2003 \xa0\n'
#  'October 2003\n'
#  'September 2003\n'
#  'August 2003\n'
#  'July 2003\n'
#  'June 2003\n'
#  'May 2003\n'
#  'April 2003\n'
#  'March 2003\n'
#  'February 2003\n'
#  'January 2003 \xa0\n'
#  'December 2002\n'
#  'November 2002\n'
#  'October 2002\n'
#  'September 2002\n'
#  'July 2002\n'
#  'June 2002\n'
#  'May 2002\n'
#  'April 2002\n'
#  'March 2002\n'
#  'February 2002\n'
#  'January 2002 \xa0\n'
#  'December 2001\n'
#  'November 2001\n'
#  'October 2001\n'
#  'September 2001\n'
#  'August 2001\n'
#  'July 2001\n'
#  'June 2001\n'
#  'May 2001\n'
#  'April 2001\n'
#  'March 2001\n'
#  'February 2001\n'
#  'January 2001 \xa0\n'
#  'December 2000\n'
#  'November 2000\n'
#  'October 2000\n'
#  'September 2000\n'
#  'August 2000\n'
#  'July 2000\n'
#  'June 2000\n'
#  'May 2000\n'
#  'April 2000\n'
#  'March 2000\n'
#  'February 2000\n'
#  'January 2000 \xa0\n'
#  'December 1999\n'
#  'November 1999\n'
#  'October 1999\n'
#  'September 1999 \xa0\n'
#  'August 1999\n'
#  'July 1999\n'
#  'June 1999\n'
#  'May')
#
#
# 5: PPL-XL=2.323, PPL-S=7.856, score=2.446
#
# ('LasPerkakas TanganPneumatica TangoGator Timid Nature Tyranitar Tyrantrum '
#  'TylerEK Timid Nature Tyrunt Ukieki Uxie Uxie-Chan Vanillish Vanillite '
#  'Vanilluxe Vaporeon Venipede Venomoth Venonat Venusaur Vespiquen Vigoroth '
#  'Victini Victreebel Vigoroth Vulpix Volbeat Volcarona Voltorb Vullaby Vulpix '
#  'Wailmer Wailord Walrein Wartortle Watchog Weavile Weedle Weepinbell Weezing '
#  'Whimsicott Whirlipede Whiscash Whismur Wigglytuff Wingull Wobbuffet Woobat '
#  'Wooper Wormadam Wurmple Wynaut Xatu Xerneas Yamask Yanma Yanmega Yveltal '
#  'Zangoose Zapdos Zebstrika Barboach Basculin Bastiodon Bayleef Bertha Bisharp '
#  'Blissey Blitzle Bronzong Bronzor Budew Buizel Bulbasaur Buneary Chikorita '
#  'Chimchar Chimecho Clefable Clefairy Cloacate Combee Corphish Corsola '
#  'Cottonee Cradily Cranidos Cresselia Croag')
#
#
# 6: PPL-XL=2.506, PPL-S=9.353, score=2.434
#
# ('Best Selling Alphabetically, A-Z Alphabetically, Z-A Price, low to high '
#  'Price, high to low Date, new to old Date, old to new Grid View List View\n'
#  '\n'
#  'Loading the player...\n'
#  '\n'
#  "If you can't get the video to play, right click here and copy/paste the link "
#  'into your browser.')
#
#
# 7: PPL-XL=3.149, PPL-S=14.846, score=2.352
#
# ("violoncelle avec accompagnement de l'adolescence: Les générations du travail "
#  'et les délaiements familiales. Cahiers de pediatri, 26, 2 (2011), pp. '
#  '189-209\n'
#  '\n'
#  "ⓘ Aiguilles-la-Sulphur-de-l'Etang ⓘ Aiguilles Séguy, S. (1931) Crude and "
#  'non-crude mineralizations of the Aiguilles Massif, Picardy, France. Bulletin '
#  'du Service Géologique Nationale, Paris\n'
#  '\n'
#  'ⓘ Monts de la Côte P.G. Pélisson : "Etude Minéralogique et Métallogénique du '
#  'District Filonien Polytype de Paulhaguet (Haute-Loire, Massif Central, '
#  'France)", Doctorate Thesis, Orléans, France, 1989\n'
#  '\n'
#  'Rhône-Alpes Allier Cazaux ⓘ Cazaux mine P.G. Pélisson : "Etude Minéralogique '
#  'et Métallogénique du District Filonien Polytype de Paulhaguet (Haute-Loire, '
#  'Massif Central, France)", Doctorate The')
#
#
# 8: PPL-XL=5.096, PPL-S=38.411, score=2.240
#
# ('since {{ user.formattedDateUserFriended }} {{ '
#  'user.formattedDateUserFriendedUnlisted }} Send this review to friends')
#
#
# 9: PPL-XL=1.760, PPL-S=3.504, score=2.217
#
# ('label[id*=\'qty\']").remove(\'qty\');\n'
#  '\n'
#  '});\n'
#  '\n'
#  '</script>\n'
#  '\n'
#  '\n'
#  '</div>\n'
#  '\n'
#  '\n'
#  '</div>\n'
#  '\n'
#  '\n'
#  '</div>\n'
#  '\n'
#  '\n'
#  '</div>\n'
#  '\n'
#  '" }, "$:/core/ui/EditTemplate/body": { "title": '
#  '"$:/core/ui/EditTemplate/body", "tags": "$:/tags/EditTemplate", "text": '
#  '"\\\\define lingo-base() $:/language/EditTemplate/\n'
#  '\n'
#  '\\\\define config-title()\n'
#  '\n'
#  '$:/config/EditTemplateFields/Visibility/$(listItem)$\n'
#  '\n'
#  '\\\\end\n'
#  '\n'
#  '\n'
#  '\\\\define config-filter()\n'
#  '\n'
#  '<$list '
#  'filter=\\"[all[shadows+tiddlers]tag[$:/tags/EditTemplate]!has[draft.of]]\\" '
#  'variable=\\"listItem\\">\n'
#  '\n'
#  '<$checkbox tiddler=<<config-title>> field=\\"text\\" checked=\\"show\\" '
#  'unchecked=\\"hide\\" default=\\"show\\"/> <span class=\\"tc-message-box\\">\n'
#  '\n'
#  '<$transclude tiddler=<<listItem>>/>\n'
#  '\n'
#  '</span>\n'
#  '\n'
#  '</$list>\n'
#  '\n'
#  '\\\\end\n'
#  '\n'
#  '\n'
#  '\\\\define message-wrap()\n'
#  '\n'
#  '{{{\n'
#  '\n'
#  '\n'
#  'cursor = moveUp? c')
#
#
# 10: PPL-XL=2.810, PPL-S=9.556, score=2.185
#
# ('favourited hidden no longer hidden\n'
#  '© 2021 IGN Entertainment, Inc.\n'
#  '\n'
#  '© 2010 IGN Entertainment, Inc.\n'
#  '\n'
#  '© 2003-2013 Take-Two Interactive Software and its subsidiaries. 2K, the 2K '
#  'logo, and Take-Two Interactive Software are all trademarks and/or registered '
#  'trademarks of Take-Two Interactive Software, Inc. All other marks and '
#  'trademarks are the property of their respective owners. All Rights '
#  'Reserved.\n'
#  '\n'
#  'Use of the software subject to license in manual & online at '
#  'https://www.take2games.com/eula/')
#
#
#
#
# ======== top sample by ratio of lower-case and normal-case perplexities: ========
# 1: PPL-XL=1.052, PPL-XL-Lower=8.723, score=42.993
#
# ('May 2016 March 2016 February 2016 January 2016 December 2015 November 2015 '
#  'October 2015 September 2015 August 2015 July 2015 June 2015 May 2015 April '
#  '2015 March 2015 February 2015 January 2015 December 2014 November 2014 '
#  'October 2014 September 2014 August 2014 July 2014 June 2014 May 2014 April '
#  '2014 March 2014 February 2014 January 2014 December 2013 November 2013 '
#  'October 2013 September 2013 August 2013 July 2013 June 2013 May 2013 April '
#  '2013 March 2013 February 2013 January 2013 December 2012 November 2012 '
#  'October 2012 September 2012 August 2012 July 2012 June 2012 May 2012 April '
#  '2012 March 2012 February 2012 January 2012 December 2011 November 2011 '
#  'October 2011 September 2011 August 2011 July 2011 June 2011 Select a '
#  "category Agriculture Bihar Votes For Its (and India's) Future BUDGET 2014 "
#  "Budget 2015: Modi's Moment of Reckoning Budget 2016: The stories behind the "
#  'numbers Chart of the Day Climate Change Cover Story Currency Chaos '
#  'Development Education Elections 2014 Employment Fact Check Governance '
#  "Newsletter Health homepage video Hunger India's Great Challenge: Health & "
#  'Sanitation IndiaSpend In The News IndiaSpend Interviews Industry '
#  'Investigations Central State Latest Headlines Latest Reports Making Sense of '
#  "Breaking News Modi's Message: India's States Reply Modi's Report Card Mumbai "
#  'Special Mumbai Special: The Revival Agenda Opinion – Videos Opinions '
#  "Pollution Poverty Prime Time: India's Grand Challenges Resources Central "
#  'State Sectors Agriculture Defence Economy & Policy Education Health '
#  'Infrastructure Snapshots States Central India Chatt')
#
#
# 2: PPL-XL=1.075, PPL-XL-Lower=4.257, score=20.047
#
# ('French Guiana French Polynesia French Southern Territories Gabon Gambia '
#  'Georgia Germany Ghana Gibraltar Greece Greenland Grenada Guadeloupe Guam '
#  'Guatemala Guernsey Guinea Guinea-Bissau Guyana Haiti Heard Island and '
#  'McDonald Islands Holy See (Vatican City State) Honduras Hong Kong Hungary '
#  'Iceland India Indonesia Iran, Islamic Republic of Iraq Ireland Isle of Man '
#  'Israel Italy Jamaica Japan Jersey Jordan Kazakhstan Kenya Kiribati Korea, '
#  "Democratic People's Republic of Korea, Republic of Kuwait Kyrgyzstan Lao "
#  "People's Democratic Republic Latvia Lebanon Lesotho Liberia Libya "
#  'Liechtenstein Lithuania Luxembourg Macao Macedonia, the former Yugoslav '
#  'Republic of Madagascar Malawi Malaysia Maldives Mali Malta Marshall Islands '
#  'Martinique Mauritania Mauritius Mayotte Mexico Micronesia, Federated States '
#  'of Moldova, Republic of Monaco Mongolia Montenegro Montserrat Morocco '
#  'Mozambique Myanmar Namibia Nauru Nepal Netherlands New Caledonia New Zealand '
#  'Nicaragua Niger Nigeria Niue Norfolk Island Northern Mariana Islands Norway '
#  'Oman Pakistan Palau Palestinian Territory, Occupied Panama Papua New Guinea '
#  'Paraguay Peru Philippines Pitcairn Poland Portugal Puerto Rico Qatar Reunion '
#  'Romania Russian Federation Rwanda Saint Barthelemy Saint Helena, Ascension '
#  'and Tristan da Cunha Saint Kitts and Nevis Saint Lucia Saint Martin (French '
#  'part) Saint Pierre and Miquelon Saint Vincent and the Gren')
#
#
# 3: PPL-XL=1.144, PPL-XL-Lower=4.901, score=11.789
#
# ('Kosovo Kuwait Kyrgyzstan Laos Latvia Lebanon Lesotho Liberia Libya '
#  'Liechtenstein Lithuania Luxembourg Macao Macedonia, The Former Yugoslav '
#  'Republic of Madagascar Malawi Malaysia Maldives Mali Malta Marshall Islands '
#  'Martinique Mauritania Mauritius Mayotte Mexico Micronesia, Federated States '
#  'of Moldova, Republic of Monaco Mongolia Montenegro Montserrat Morocco '
#  'Mozambique Myanmar Namibia Nauru Nepal Netherlands Netherlands Antilles New '
#  'Caledonia New Zealand Nicaragua Niger Nigeria Niue Norfolk Island Northern '
#  'Mariana Islands Norway Oman Pakistan Palau Palestinian Territory, Occupied '
#  'Panama Papua New Guinea Paraguay Peru Philippines Pitcairn Poland Portugal '
#  'Puerto Rico Qatar Reunion Romania Russian Federation Rwanda Saint Barthélemy '
#  'Saint Helena, Ascension and Tristan da Cunha Saint Kitts and Nevis Saint '
#  'Lucia Saint Martin (French part) Saint Pierre and Miquelon Saint Vincent and '
#  'the Grenadines Samoa San Marino Sao Tome and Principe Saudi Arabia Senegal '
#  'Serbia Seychelles Sierra Leone Singapore Sint Maarten (Dutch part) Slovakia '
#  'Slovenia Solomon Islands Somalia South Africa South Georgia and the South '
#  'Sandwich Islands South Korea South Sudan Spain Sri Lanka Sudan Suriname '
#  'Svalbard and Jan Mayen Swaziland Sweden Switzerland Syrian Arab Republic '
#  'Taiwan Tajikistan Tanzania, United Republic of Thailand Timor-Leste Togo '
#  'Tokelau')
#
#
# 4: PPL-XL=1.164, PPL-XL-Lower=3.620, score=8.488
#
# ('and Saba Bosnia and Herzegovina Botswana Bouvet Island Brazil British Indian '
#  'Ocean Territory Brunei Darussalam Bulgaria Burkina Faso Burundi Cameroon '
#  'Canada Cape Verde Cayman Islands Central African Republic Chad Chile China '
#  'Christmas Island Cocos (Keeling) Islands Colombia Comoros Congo Congo, the '
#  'Democratic Republic of the Cook Islands Costa Rica Croatia Cuba Curaçao '
#  "Cyprus Czech Republic Côte d'Ivoire Denmark Djibouti Dominica Dominican "
#  'Republic Ecuador Egypt El Salvador Equatorial Guinea Eritrea Estonia '
#  'Ethiopia Falkland Islands (Malvinas) Faroe Islands Fiji Finland France '
#  'French Guiana French Polynesia French Southern Territories Gabon Gambia '
#  'Georgia Germany Ghana Gibraltar Greece Greenland Grenada Guadeloupe Guam '
#  'Guatemala Guernsey Guinea Guinea-Bissau Guyana Haiti Heard Island and '
#  'McDonald Islands Holy See (Vatican City State) Honduras Hong Kong Hungary '
#  'Iceland India Indonesia Iran, Islamic Republic of Iraq Ireland Isle of Man '
#  'Israel Italy Jamaica Japan Jersey Jordan Kazakhstan Kenya Kiribati Korea, '
#  "Democratic People's Republic of Korea, Republic of Kuwait Kyrgyzstan Lao "
#  "People's Democratic Republic Latvia Lebanon Lesotho Liberia Libyan Arab "
#  'Jamahiriya Liechtenstein Lithuania Luxembourg Macao Macedonia, the former '
#  'Yugoslav Republic of Madagascar Malawi Malaysia Maldives Mali Malta Marshall '
#  'Islands Martinique Mauritania Mauritius')
#
#
# 5: PPL-XL=1.818, PPL-XL-Lower=35.262, score=5.961
#
# ('Z M9.5,6.7896528,6.87408853 rot = 6.423729E-08,2.146564E-09,1.256059E-07,-1 '
#  'attRot = 0,0,0,1 mir = 1,1,1 istg = 0 dstg = 0 sidx = -1 sqor = -1 attm = 1 '
#  'sym = solarPanels5_4294351446 srfN = srfAttach,wingConnector_4293463302 '
#  'EVENTS { } ACTIONS { } MODULE { name = ModuleDeployableSolarPanel isEnabled '
#  '= True currentRotation = (0, 0, 0, 0) stateString = RETRACTED '
#  'storedAnimationTime = 0 storedAnimationSpeed = 0 EVENTS { Extend { active = '
#  'True guiActive = True guiIcon = Extend Panels guiName = Extend Panels '
#  'category = Extend Panels guiActiveUnfocused = True unfocusedRange = 4 '
#  'externalToEVAOnly = True } Retract { active = True guiActive = True guiIcon '
#  '= Retract Panels guiName = Retract Panels category = Retract Panels '
#  'guiActiveUnfocused = True unfocusedRange = 4 externalToEVAOnly = True } } '
#  'ACTIONS { ExtendPanelsAction { actionGroup = Custom09 } ExtendAction { '
#  'actionGroup = None } RetractAction { actionGroup = None } } } } PART { part '
#  '= solarPanels5_4294351446')
#
#
# 6: PPL-XL=2.376, PPL-XL-Lower=136.886, score=5.684
#
# ('MetropolitanFrench GuianaFrench PolynesiaFrench South '
#  'AfricaGabonGhanaGambiaGeorgiaGerman Federal RepublicGeertland, '
#  'NetherlandsGreenlandGuadeloupeGuamGuatemalaGuineaGuinea-BissauGuyanaHaitiHondurasHonduras-BoliviaHong '
#  'KongHungaryIcelandIcelandic '
#  'IslandsIndiaIndonesiaIranIraqIrelandIsraelItalyJamaicaJamaica-BarbadosJapanJordanKazakhstanKenyaKiribatiKorea, '
#  'RepublicKorea, Republic '
#  'ofKosovoKuwaitKyrgyzstanLaosLatviaLebanonLiberiaLibyaLiechtensteinLibertyLibya-QaddafiLesothoLithuaniaLuxembourgMacaoMadagascarMadagascar-BarbadosMacedoniaMadridMalawiMalaysiaMaldivesMaliMaltaMauritaniaMauritiusMassachusettsMauritiusMontenegroMinamMongoliaMozambiqueMyanmarNamibiaNepalNetherlandsNew '
#  'CaledoniaNew ZealandNew Zealand-LiaotiaNicaraguaNigerNorth '
#  'KoreaNorwayOmanPakistanPanamaOmanPeruPitcairnPolandPortugalPortugal-AlgarvePuerto')
#
#
# 7: PPL-XL=1.153, PPL-XL-Lower=2.059, score=5.075
#
# ('page.\n'
#  'Click here to toggle editing of individual sections of the page (if '
#  'possible). Watch headings for an "edit" link when available.\n'
#  '\n'
#  'Append content without editing the whole page source.\n'
#  '\n'
#  'Check out how this page has evolved in the past.\n'
#  '\n'
#  'If you want to discuss contents of this page - this is the easiest way to do '
#  'it.\n'
#  '\n'
#  'View and manage file attachments for this page.\n'
#  '\n'
#  'Change the name (also URL address, possibly the category) of the page.\n'
#  '\n'
#  'View wiki source for this page without editing.\n'
#  '\n'
#  'View/set parent page (used for creating breadcrumbs and structured layout).\n'
#  '\n'
#  'Notify administrators if there is objectionable content in this page.\n'
#  '\n'
#  'Something does not work as expected? Find out what you can do.\n'
#  '\n'
#  'General Wikidot.com documentation and help section.\n'
#  '\n'
#  'Wikidot.com Terms of Service - what you can, what you should not etc.\n'
#  '\n'
#  'Wikidot.com Privacy Policy.')
#
#
# 8: PPL-XL=1.292, PPL-XL-Lower=3.223, score=4.566
#
# ('Belarus Belgium Belize Benin Bermuda Bhutan Bolivia Bosnia And Herzegovina '
#  'Botswana Brazil Bulgaria Burkina Faso Burundi Cambodia Cameroon Canadian '
#  'Cape Verde Cayman Islands Central African Republic Chad Chile China '
#  'Christmas Island Cocos Islands Colombia Comoros Congo Cook Islands Costa '
#  "Rica Cote D'Ivoire Croatia Cuba Cyprus Czech Republic Democratic Republic of "
#  'Congo Denmark Djibouti Dominica Dominican Republic East Timor Ecuador Egypt '
#  'El Salvador Equatorial Guinea Eritrea Estonia Ethiopia Falkland Islands '
#  'Faroe Islands Fiji Finland France French Guiana French Polynesia French '
#  'Southern Territories Gabon Gambia Georgia Germany Ghana Gibraltar Greece '
#  'Greenland Grenada Guadeloupe Guam Guatemala Guernsey Guinea Guinea-bissau '
#  'Guyana Haiti Heard Island And Mcdonald Islands Holy See (Vatican City State) '
#  'Honduras Hong Kong Hungary Iceland India Indonesia Iran Iraq Ireland Isle Of '
#  'Man Israel Italy Jamaica Japan Jersey Jordan Kazakhstan Kenya Kiribati '
#  'Kosovo Kuwait Kyrgyzstan Laos Latvia Lebanon Lesotho Liberia Libya '
#  'Liechtenstein Lithuania Luxembourg Macau Macedonia Madagascar Malawi '
#  'Malaysia Maldives Mali Malta Marshall Islands Martinique Mauritania '
#  'Mauritius Mayotte Mexico Micronesia, Federated States Of Moldova Monaco '
#  'Mongolia Montenegro Montserrat Morocco Mozambique Myanmar (Burma) Namibia '
#  'Nauru Nepal Netherlands Netherlands Antilles New Caledonia New Zealand '
#  'Nicaragua')
#
#
# 9: PPL-XL=2.226, PPL-XL-Lower=12.182, score=3.124
#
# ('Nakaya April 13, 2018 October 14, 2018 Osaka University School of Medicine\n'
#  '\n'
#  'Osaka, Japan\n'
#  '\n'
#  '2 NCT03495884 Completed\n'
#  '\n'
#  'Has Results Efficacy and Safety of Antidepressants in Treatment-Resistant '
#  'Depression Efficacy\n'
#  '\n'
#  'Post-Treatment Depression\n'
#  '\n'
#  '(and 2 more...) Behavioral: Psychotherapy + Cognitive Behavioral Therapy\n'
#  '\n'
#  'Drug: SSRI\n'
#  '\n'
#  'Drug: Placebo Interventional\n'
#  '\n'
#  'Phase 3\n'
#  '\n'
#  'Phase 4 Yale University Other Allocation: Randomized\n'
#  '\n'
#  'Intervention Model: Factorial Assignment\n'
#  '\n'
#  'Masking: Quadruple (Participant, Care Provider, Investigator, Outcomes '
#  'Assessor)\n'
#  '\n'
#  'Primary Purpose: Treatment Mean Change From Baseline In Change From Baseline '
#  'in Clinical Global Impression-Severity Scores (CGI-SF)\n'
#  '\n'
#  'Change From Baseline In Change From Baseline in Clinical Global '
#  'Impression-Improvement Scores (CGI-I)\n'
#  '\n'
#  'Change From Baseline in Change From Baseline in Beck Depression Inventory '
#  '(BDI) Total Score\n'
#  '\n'
#  'Change From Baseline In Change From Baseline in Montgomery-Asberg Depression '
#  'Rating Scale (MADRS) Total Score\n'
#  '\n'
#  '(and 6 more...) 72 All 40 Years to 65 Years (Adult, Older Adult) NCT03495884')
#
#
# 10: PPL-XL=2.506, PPL-XL-Lower=12.805, score=2.776
#
# ('Best Selling Alphabetically, A-Z Alphabetically, Z-A Price, low to high '
#  'Price, high to low Date, new to old Date, old to new Grid View List View\n'
#  '\n'
#  'Loading the player...\n'
#  '\n'
#  "If you can't get the video to play, right click here and copy/paste the link "
#  'into your browser.')
#
#
#
#
# ======== top sample by ratio of Zlib entropy and XL perplexity: ========
# 1: PPL-XL=1.052, Zlib=666.000, score=13219.885
#
# ('May 2016 March 2016 February 2016 January 2016 December 2015 November 2015 '
#  'October 2015 September 2015 August 2015 July 2015 June 2015 May 2015 April '
#  '2015 March 2015 February 2015 January 2015 December 2014 November 2014 '
#  'October 2014 September 2014 August 2014 July 2014 June 2014 May 2014 April '
#  '2014 March 2014 February 2014 January 2014 December 2013 November 2013 '
#  'October 2013 September 2013 August 2013 July 2013 June 2013 May 2013 April '
#  '2013 March 2013 February 2013 January 2013 December 2012 November 2012 '
#  'October 2012 September 2012 August 2012 July 2012 June 2012 May 2012 April '
#  '2012 March 2012 February 2012 January 2012 December 2011 November 2011 '
#  'October 2011 September 2011 August 2011 July 2011 June 2011 Select a '
#  "category Agriculture Bihar Votes For Its (and India's) Future BUDGET 2014 "
#  "Budget 2015: Modi's Moment of Reckoning Budget 2016: The stories behind the "
#  'numbers Chart of the Day Climate Change Cover Story Currency Chaos '
#  'Development Education Elections 2014 Employment Fact Check Governance '
#  "Newsletter Health homepage video Hunger India's Great Challenge: Health & "
#  'Sanitation IndiaSpend In The News IndiaSpend Interviews Industry '
#  'Investigations Central State Latest Headlines Latest Reports Making Sense of '
#  "Breaking News Modi's Message: India's States Reply Modi's Report Card Mumbai "
#  'Special Mumbai Special: The Revival Agenda Opinion – Videos Opinions '
#  "Pollution Poverty Prime Time: India's Grand Challenges Resources Central "
#  'State Sectors Agriculture Defence Economy & Policy Education Health '
#  'Infrastructure Snapshots States Central India Chatt')
#
#
# 2: PPL-XL=1.075, Zlib=748.000, score=10351.788
#
# ('French Guiana French Polynesia French Southern Territories Gabon Gambia '
#  'Georgia Germany Ghana Gibraltar Greece Greenland Grenada Guadeloupe Guam '
#  'Guatemala Guernsey Guinea Guinea-Bissau Guyana Haiti Heard Island and '
#  'McDonald Islands Holy See (Vatican City State) Honduras Hong Kong Hungary '
#  'Iceland India Indonesia Iran, Islamic Republic of Iraq Ireland Isle of Man '
#  'Israel Italy Jamaica Japan Jersey Jordan Kazakhstan Kenya Kiribati Korea, '
#  "Democratic People's Republic of Korea, Republic of Kuwait Kyrgyzstan Lao "
#  "People's Democratic Republic Latvia Lebanon Lesotho Liberia Libya "
#  'Liechtenstein Lithuania Luxembourg Macao Macedonia, the former Yugoslav '
#  'Republic of Madagascar Malawi Malaysia Maldives Mali Malta Marshall Islands '
#  'Martinique Mauritania Mauritius Mayotte Mexico Micronesia, Federated States '
#  'of Moldova, Republic of Monaco Mongolia Montenegro Montserrat Morocco '
#  'Mozambique Myanmar Namibia Nauru Nepal Netherlands New Caledonia New Zealand '
#  'Nicaragua Niger Nigeria Niue Norfolk Island Northern Mariana Islands Norway '
#  'Oman Pakistan Palau Palestinian Territory, Occupied Panama Papua New Guinea '
#  'Paraguay Peru Philippines Pitcairn Poland Portugal Puerto Rico Qatar Reunion '
#  'Romania Russian Federation Rwanda Saint Barthelemy Saint Helena, Ascension '
#  'and Tristan da Cunha Saint Kitts and Nevis Saint Lucia Saint Martin (French '
#  'part) Saint Pierre and Miquelon Saint Vincent and the Gren')
#
#
# 3: PPL-XL=1.051, Zlib=373.000, score=7473.002
#
# ('December 2018 November 2018 October 2018 September 2018 August 2018 July '
#  '2018 June 2018 May 2018 April 2018 March 2018 February 2018 January 2018 '
#  'December 2017 November 2017 October 2017 September 2017 August 2017 July '
#  '2017 June 2017 May 2017 April 2017 March 2017 February 2017 January 2017 '
#  'December 2016 November 2016 October 2016 September 2016 August 2016 July '
#  '2016 June 2016 May 2016 April 2016 March 2016 February 2016 January 2016 '
#  'December 2015 November 2015 October 2015 September 2015 August 2015 July '
#  '2015 June 2015 May 2015 April 2015 March 2015 February 2015 January 2015 '
#  'December 2014 November 2014 October 2014 September 2014 August 2014 July '
#  '2014 June 2014 May 2014 April 2014 March 2014 February 2014 January 2014 '
#  'December 2013 November 2013 October 2013 September 2013 August 2013 July '
#  '2013 June 2013 May 2013 April 2013 March 2013 February 2013 January 2013 '
#  'December 2012 November 2012 October 2012 September 2012 August 2012 July '
#  '2012 June 2012 May 2012 April 2012 March 2012 February 2012 January 2012 '
#  'December 2011 November 2011 October 2011 September 2011 August 2011 July '
#  '2011 June 2011 May 2011 April 2011 March 2011 February 2011 January 2011 '
#  'December 2010 November 2010 October 2010 September 2010 August 2010 July '
#  '2010 June 2010 May 2010 April 2010 March 2010 February 2010 January 2010 '
#  'December 2009 November 2009 October 2009 September 2009 August 2009 July '
#  '2009 June 2009 May 2009 April 2009 March 2009 February 2009 January 2009 '
#  'December 2008 November 2008 October 2008 September 2008 August 2008 July '
#  '2008 June 2008 May 2008 April 2008 March 2008 February 2008 January 2008 '
#  'December 2007')
#
#
# 4: PPL-XL=1.144, Zlib=735.000, score=5451.420
#
# ('Kosovo Kuwait Kyrgyzstan Laos Latvia Lebanon Lesotho Liberia Libya '
#  'Liechtenstein Lithuania Luxembourg Macao Macedonia, The Former Yugoslav '
#  'Republic of Madagascar Malawi Malaysia Maldives Mali Malta Marshall Islands '
#  'Martinique Mauritania Mauritius Mayotte Mexico Micronesia, Federated States '
#  'of Moldova, Republic of Monaco Mongolia Montenegro Montserrat Morocco '
#  'Mozambique Myanmar Namibia Nauru Nepal Netherlands Netherlands Antilles New '
#  'Caledonia New Zealand Nicaragua Niger Nigeria Niue Norfolk Island Northern '
#  'Mariana Islands Norway Oman Pakistan Palau Palestinian Territory, Occupied '
#  'Panama Papua New Guinea Paraguay Peru Philippines Pitcairn Poland Portugal '
#  'Puerto Rico Qatar Reunion Romania Russian Federation Rwanda Saint Barthélemy '
#  'Saint Helena, Ascension and Tristan da Cunha Saint Kitts and Nevis Saint '
#  'Lucia Saint Martin (French part) Saint Pierre and Miquelon Saint Vincent and '
#  'the Grenadines Samoa San Marino Sao Tome and Principe Saudi Arabia Senegal '
#  'Serbia Seychelles Sierra Leone Singapore Sint Maarten (Dutch part) Slovakia '
#  'Slovenia Solomon Islands Somalia South Africa South Georgia and the South '
#  'Sandwich Islands South Korea South Sudan Spain Sri Lanka Sudan Suriname '
#  'Svalbard and Jan Mayen Swaziland Sweden Switzerland Syrian Arab Republic '
#  'Taiwan Tajikistan Tanzania, United Republic of Thailand Timor-Leste Togo '
#  'Tokelau')
#
#
# 5: PPL-XL=1.164, Zlib=736.000, score=4855.572
#
# ('and Saba Bosnia and Herzegovina Botswana Bouvet Island Brazil British Indian '
#  'Ocean Territory Brunei Darussalam Bulgaria Burkina Faso Burundi Cameroon '
#  'Canada Cape Verde Cayman Islands Central African Republic Chad Chile China '
#  'Christmas Island Cocos (Keeling) Islands Colombia Comoros Congo Congo, the '
#  'Democratic Republic of the Cook Islands Costa Rica Croatia Cuba Curaçao '
#  "Cyprus Czech Republic Côte d'Ivoire Denmark Djibouti Dominica Dominican "
#  'Republic Ecuador Egypt El Salvador Equatorial Guinea Eritrea Estonia '
#  'Ethiopia Falkland Islands (Malvinas) Faroe Islands Fiji Finland France '
#  'French Guiana French Polynesia French Southern Territories Gabon Gambia '
#  'Georgia Germany Ghana Gibraltar Greece Greenland Grenada Guadeloupe Guam '
#  'Guatemala Guernsey Guinea Guinea-Bissau Guyana Haiti Heard Island and '
#  'McDonald Islands Holy See (Vatican City State) Honduras Hong Kong Hungary '
#  'Iceland India Indonesia Iran, Islamic Republic of Iraq Ireland Isle of Man '
#  'Israel Italy Jamaica Japan Jersey Jordan Kazakhstan Kenya Kiribati Korea, '
#  "Democratic People's Republic of Korea, Republic of Kuwait Kyrgyzstan Lao "
#  "People's Democratic Republic Latvia Lebanon Lesotho Liberia Libyan Arab "
#  'Jamahiriya Liechtenstein Lithuania Luxembourg Macao Macedonia, the former '
#  'Yugoslav Republic of Madagascar Malawi Malaysia Maldives Mali Malta Marshall '
#  'Islands Martinique Mauritania Mauritius')
#
#
# 6: PPL-XL=1.079, Zlib=272.000, score=3590.637
#
# ('2010 September 2010 August 2010 July 2010 June 2010 May 2010 April 2010 '
#  'March 2010 February 2010 January 2010 December 2009 November 2009 October '
#  '2009 September 2009 August 2009 July 2009 June 2009 May 2009 April 2009 '
#  'March 2009 February 2009 January 2009 December 2008 November 2008 October '
#  '2008 September 2008 August 2008 July 2008 June 2008 May 2008 April 2008 '
#  'March 2008 February 2008 January 2008 December 2007 November 2007 October '
#  '2007 September 2007 August 2007 July 2007 June 2007 May 2007 April 2007 '
#  'March 2007 February 2007 January 2007 December 2006 November 2006 October '
#  '2006 September 2006 August 2006 July 2006 June 2006 May 2006 April 2006 '
#  'March 2006 February 2006 January 2006 December 2005 November 2005 October '
#  '2005 September 2005 August 2005 July 2005 June 2005 May 2005 April 2005 '
#  'March 2005 February 2005 January 2005 December 2004 November 2004 October '
#  '2004 September 2004 August 2004 July 2004 June 2004 May 2004 April 2004 '
#  'March 2004 February 2004 January 2004 December 2003 November 2003 October '
#  '2003 September 2003 August 2003 July 2003')
#
#
# 7: PPL-XL=1.153, Zlib=464.000, score=3259.589
#
# ('page.\n'
#  'Click here to toggle editing of individual sections of the page (if '
#  'possible). Watch headings for an "edit" link when available.\n'
#  '\n'
#  'Append content without editing the whole page source.\n'
#  '\n'
#  'Check out how this page has evolved in the past.\n'
#  '\n'
#  'If you want to discuss contents of this page - this is the easiest way to do '
#  'it.\n'
#  '\n'
#  'View and manage file attachments for this page.\n'
#  '\n'
#  'Change the name (also URL address, possibly the category) of the page.\n'
#  '\n'
#  'View wiki source for this page without editing.\n'
#  '\n'
#  'View/set parent page (used for creating breadcrumbs and structured layout).\n'
#  '\n'
#  'Notify administrators if there is objectionable content in this page.\n'
#  '\n'
#  'Something does not work as expected? Find out what you can do.\n'
#  '\n'
#  'General Wikidot.com documentation and help section.\n'
#  '\n'
#  'Wikidot.com Terms of Service - what you can, what you should not etc.\n'
#  '\n'
#  'Wikidot.com Privacy Policy.')
#
#
# 8: PPL-XL=1.292, Zlib=768.000, score=2996.612
#
# ('Belarus Belgium Belize Benin Bermuda Bhutan Bolivia Bosnia And Herzegovina '
#  'Botswana Brazil Bulgaria Burkina Faso Burundi Cambodia Cameroon Canadian '
#  'Cape Verde Cayman Islands Central African Republic Chad Chile China '
#  'Christmas Island Cocos Islands Colombia Comoros Congo Cook Islands Costa '
#  "Rica Cote D'Ivoire Croatia Cuba Cyprus Czech Republic Democratic Republic of "
#  'Congo Denmark Djibouti Dominica Dominican Republic East Timor Ecuador Egypt '
#  'El Salvador Equatorial Guinea Eritrea Estonia Ethiopia Falkland Islands '
#  'Faroe Islands Fiji Finland France French Guiana French Polynesia French '
#  'Southern Territories Gabon Gambia Georgia Germany Ghana Gibraltar Greece '
#  'Greenland Grenada Guadeloupe Guam Guatemala Guernsey Guinea Guinea-bissau '
#  'Guyana Haiti Heard Island And Mcdonald Islands Holy See (Vatican City State) '
#  'Honduras Hong Kong Hungary Iceland India Indonesia Iran Iraq Ireland Isle Of '
#  'Man Israel Italy Jamaica Japan Jersey Jordan Kazakhstan Kenya Kiribati '
#  'Kosovo Kuwait Kyrgyzstan Laos Latvia Lebanon Lesotho Liberia Libya '
#  'Liechtenstein Lithuania Luxembourg Macau Macedonia Madagascar Malawi '
#  'Malaysia Maldives Mali Malta Marshall Islands Martinique Mauritania '
#  'Mauritius Mayotte Mexico Micronesia, Federated States Of Moldova Monaco '
#  'Mongolia Montenegro Montserrat Morocco Mozambique Myanmar (Burma) Namibia '
#  'Nauru Nepal Netherlands Netherlands Antilles New Caledonia New Zealand '
#  'Nicaragua')
#
#
# 9: PPL-XL=1.090, Zlib=254.000, score=2946.145
#
# ('March 2010 February 2010 January 2010 December 2009 November 2009 October '
#  '2009 September 2009 August 2009 July 2009 June 2009 May 2009 April 2009 '
#  'March 2009 February 2009 January 2009 December 2008 November 2008 October '
#  '2008 September 2008 August 2008 July 2008 June 2008 May 2008 April 2008 '
#  'March 2008 February 2008 January 2008 December 2007 November 2007 October '
#  '2007 September 2007 August 2007 July 2007 June 2007 May 2007 April 2007 '
#  'March 2007 February 2007 January 2007 December 2006 November 2006 October '
#  '2006 September 2006 August 2006 July 2006 June 2006 May 2006 April 2006 '
#  'March 2006 February 2006 January 2006 December 2005 November 2005 October '
#  '2005 September 2005 August 2005 July 2005 June 2005 May 2005 April 2005 '
#  'March 2005 February 2005 January 2005 December 2004 November 2004 October '
#  '2004 September 2004 August 2004 July 2004 June 2004 May 2004 April 2004 '
#  'March 2004 February 2004 January 2004 December 2003 November 2003 October '
#  '2003 September 2003 August 2003 July 2003')
#
#
# 10: PPL-XL=1.081, Zlib=215.000, score=2751.891
#
# ('4246 4247 4248 4249 4250 4251 4252 4253 4254 4255 4256 4257 4258 4259 4260 '
#  '4261 4262 4263 4264 4265 4266 4267 4268 4269 4270 4271 4272 4273 4274 4275 '
#  '4276 4277 4278 4279 4280 4281 4282 4283 4284 4285 4286 4287 4288 4289 4290 '
#  '4291 4292 4293 4294 4295 4296 4297 4298 4299 4300 4301 4302 4303 4304 4305 '
#  '4306 4307 4308 4309 4310 4311 4312 4313 4314 4315 4316 4317 4318 4319 4320 '
#  '4321 4322 4323 4324 4325 4326 4327 4328 4329 4330 4331 4332 4333 4334 4335 '
#  '4336 4337 4338 4339 4340 4341 4342 4343 4344 4345 4346 4347 4348 4349 4350 '
#  '4351 4352 4353 4354 4355 4356 4357 4358 4359 4360 4361 4362 4363 4364 4365 '
#  '4366 4367 4368 4369 4370 4371 4372 4373 4374 4375 4376 4377 4378')

# %% [markdown]
# Enhancement to defend the exposure of training data using the parameters of the model

# %%
# !python3 extraction_enhancement.py --N 100 --internet-sampling --wet-file commoncrawl.warc.wet
# Out:
# using device: cuda
# Loading common crawl...
# Loading GPT2...
# Loaded 0 samples. 100 more samples needed.
# Loaded checkpoint: 0 samples already generated.
# Remaining samples to generate: 100
#   0% 0/100 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  10% 10/100 [00:19<02:55,  1.95s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  20% 20/100 [00:37<02:29,  1.86s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  30% 30/100 [00:56<02:10,  1.86s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  40% 40/100 [01:15<01:53,  1.90s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  50% 50/100 [01:35<01:36,  1.93s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  60% 60/100 [01:54<01:16,  1.91s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  70% 70/100 [02:14<00:58,  1.95s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  80% 80/100 [02:34<00:39,  1.96s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  90% 90/100 [02:52<00:19,  1.92s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 100% 100/100 [03:11<00:00,  1.91s/it]
# ======== top sample by XL perplexity: ========
# 1: PPL=63.861, , score=-4.157
#
# ('Angle 1 21\n'
#  'Wrestling, Mr. Olympia 1 4 23 12 5 28 22 27 27 24 26 23 30 29 22\n'
#  'Wear weight (lbs!) 6,500 1 4 13 2,350 32 20 18 17 15 33 29 38 2 14 1 29 26 '
#  '10 10 4 5 28 19 1 21 1\n'
#  'Body size: 34" 32 1 5 5 8 33 38 31 3 16 3 10 35 39 5 0 22 31\n'
#  'T-score 35 0 29 19 30 13 2 4 12 14 33 31 13 10 5 19 36 1 20 5 28 6 21 34 8 '
#  '21 6 14 27 37 4 19\n'
#  'Dumbells Height 18 28 32 33 17 36 20 8 1 10 39 2 15 33 1 31 5 12 40 32 24 19 '
#  '31 40 5 9 8 22 43 21 8 29 14 43 5 9 42 6 13 32 24\n'
#  'Pineconifer\n'
#  'Easterlin \xa0\n'
#  '1.75 miles 3 11 9 28 11 20 16 27 25 6 4 7 8 15 37 30 16 4 2 38 32 6 0 21 20 '
#  '18 30 37 38 32 22 2 8 43 41 23 6 31 22 44 16 22 4 5 35\n'
#  'Nash Height 24 34 2 11 34 28 16 13 18 8 11 44 34 13 17 5 9 18 31 1 29 27 9 3 '
#  '15 3 9\n'
#  '2)\xa0 2')
#
#
# 2: PPL=84.426, , score=-4.436
#
# ('Shipping costs are non-refundable. If something is incorrectly dispatched we '
#  'will exchange immediately. If something already is incorrect it is at our '
#  'cost no expense therefore do give at home as soon after sending a '
#  'notification via a contact of registered.\n'
#  '\n'
#  ' It gives us much appreciated and will take away the problem with us and '
#  'delivery people when to deliver items that are defective but do get damaged '
#  "upon a customs inspection. It's only by taking extra measures at customs "
#  'with some other steps by ourselves is something more time costly on both the '
#  'sender as a whole when this situation would result due there having no '
#  'control or any contact if not you. And even at the receiving site they will '
#  'get a customs control inspection not us since to deliver an object by '
#  'yourself a little time is more difficult to it with any delays and problems '
#  'resulting. (Even some extra cost are usually done so on that end.) Also any '
#  'delay would give another time time for Customs inspection but this might '
#  "result and increase up with time and cost the amount it'd be, or might be "
#  'done.\n'
#  '\n'
#  ': we need an idea if this post on "Tearoom Bunkertickets" on www-users '
#  'mailing to each other might of the matter the "tire/lose pressure in '
#  'steering", I might of have this if "barn find the tire loose" because I')
#
#
# 3: PPL=86.821, , score=-4.464
#
# ('gonorrhea, and herpes are some of the conditions to go away naturally. To '
#  'improve things and improve healing you usually just can choose an effective '
#  'antibiotics on an every few treatments as long she takes any medicine '
#  'prescribed out there so a great deal in medicine which could affect its '
#  'effect. For more, read your medication guides of prescription for it and '
#  'discuss. However do make this first point first as if, because for you or as '
#  'doctor, has you or you child is unable taking treatment because if they have '
#  'or have come and ask your and let that is okay then they must tell '
#  'everything and as she is with the mother, have also discussed with or about '
#  'her and then take away any concern of concern. After it and they both feel '
#  'well again.\n'
#  'What you do after sex can even give it the greatest and the better '
#  'advantage\n'
#  'This sex can even aid it so so very for her too in any possible for sexual '
#  'relationship because also make them get in sex and that is how we get and '
#  'can do get ourselves ready or not have all it and get up again because in '
#  'her sex is and the very first thing as such in which we both has an ideal '
#  'way to do because her sex in itself and for many a mother with the woman is '
#  'an ideal type do so very best when not do she was ever to ever. In so')
#
#
# 4: PPL=92.930, , score=-4.532
#
# ('1059 1060 1061 1062 1063 1061410591 12041 305780 3078336031 80161 1302 '
#  '1787173815 1728184035 365563 120400 81669121425 1647010973 102847 3156269916 '
#  '1313688814 518688979 78897161417 1064159818 2414572363 1316126432 3567987839 '
#  '7964293923 2680880164 2558552619 02844381657 2877396569 9263799168 '
#  '2712982594 4940883893 4570455986 1879885076 2444366902 3040369865 1664691656 '
#  '4835145775 1338555894 2089797845 2817097690 4967236916 0952929459 3501334563 '
#  '2617895907 3916572266 9986639307 2523122521 0286913199 1515483548 3126256975 '
#  '2769504813 2815262958 1716885063 2326156880 5063692785 28659945')
#
#
# 5: PPL=95.503, , score=-4.559
#
# ('12.020\n'
#  'KOBAY 4.790 27\n'
#  'DUNCER 3\n'
#  'WILLAUPEE 4 0,99B 3.100 5 10.70 -12 12 50 4 5 SACKERSLEY 12 7.00 -13 10 -20 '
#  '6 CECIAN 10 6 50 18.70 27 32 20 22 PRAIGHT/WASEM 3 CASTALOGAN 24 12 5 7 '
#  'CERRAS 2 14 6 10 SCHOLESTED 8 15 20 2 13 BUSH 1 6 4 15 MACKARRY 12 7 28 8 22 '
#  'JACKIE 2 16 18 20 RALFO 20 17 9 12\n'
#  'HIST 31 CUMONARY OF TARGET OF ENTRATHLONA 2 12 17 19 RACHAN 8 20 27 10 26 '
#  'DEXterG 3 21 32 23 27 NACHM 4 23 36 12 41 BLOGFIT 15 34 40 20 47 HAPPON 4 28 '
#  '32 23 61 BOLEROZ 26 33 26 50 TEMPO 20 25 44 5 67 FRANK 6 22 18 35 66 CARLIN '
#  '11 24 24 23 82 SMIDY 3 2 17 13 96 BRODESNIA 3 4 10 12 112 COREEN 2 6 16 13 '
#  '150 REEF 13 8 22 24 153 TRACKSTREIGHT 1 9')
#
#
# 6: PPL=97.495, , score=-4.580
#
# ('8.13689655,2.84193784 '
#  '...')
#
#
# 7: PPL=102.643, , score=-4.631
#
# ('(all items published the previous day)\n'
#  'Won this on. View its details >>\n'
#  'The previous page\n'
#  'The new issue,\xa0 12 Oct. 2008: New paper urn link The earlier entry from '
#  'my website\n'
#  '\xa0There seem to not be good, full reports of what goes down. See what '
#  'comes of the reports.\xa0 I have posted these pictures here before when you '
#  'find their first appearing online...and maybe also this year! You may '
#  'download a\xa0 printable version')
#
#
# 8: PPL=103.120, , score=-4.636
#
# ('first presentation was a bit boring).\n'
#  'Troy Williams then presented our last talk after he said last that he just '
#  'has another two weeks in school in preparation and his parents paid, well '
#  'for the $10 a hand I took care with he got to ride across on board while I '
#  'ate, then while I ran off I got on the airplane he drove right there in line '
#  'where everyone went "You\'re that person…You know…" But even this could give '
#  "anyone away they didn't see, we even showed some screen shot videos just "
#  'because for him it made no sense the he already knew everything except my ID '
#  'for some "privleuvenesse\', we also left on our laptops he looked my '
#  'information off the screen…and at 4 miles there was another turn signal just '
#  'next with the blue square and our GPS that let both sides know he was '
#  'already out...then I pulled from him all but 2 dollars left to the time a '
#  'new sign and some small boxes were still for new signage, and a truck with '
#  'no registration just up in my way with people coming from there who knew '
#  'something happened then at this moment all their hands on a phone had a '
#  'green screen…as in a very close up to it..there is nothing behind your house '
#  'except it all happens, or what could have happened there or on one day')
#
#
# 9: PPL=103.971, , score=-4.644
#
# ('shall be made of hammered work; its cups, which make use here\n'
#  '(vn, 2 & 14 par-d, v. i sq. ad. 11), & other parts also so that any more '
#  'will serve the end. But the form thereof at most will admit little more, '
#  'when at will done or put by with hands at random by one; I make there was as '
#  'one thing only used unto his mouth and other used more than by both to them '
#  'alone and then with great intent for more or fewer at whim but also for '
#  'others greater to use; nor I suppose one thing must always suffice of a '
#  'perfect kind and perfect quantity when either used not as we see many men '
#  'have use, as when you see the small cups and some very short at others much '
#  'of large proportion with their other uses but to them, as one is by common '
#  'custom more of use if taken away and another greater it so I say this should '
#  'be done if either more small (where that one part hath much that they could '
#  'take aye they use thereof so a wise & cunning hand thereat as many other as '
#  "it's to say more) are made; for it seems them they used very common by "
#  'nature not to be good at the most proper, that we may see the common and '
#  'right order how ever many parts made at pleasure we')
#
#
# 10: PPL=105.826, , score=-4.662
#
# ('V&A Museum of Childhood, London and The Centre Against Cruelty London, is in '
#  'part dedicated the exhibit titled, This Isn "The Day I Kewished Up, but the '
#  'World Came, a book from 2003 chroniclinh t he impact o r AIDS, sex s&t, & '
#  'furs by artists\n'
#  '. It had opened this Friday, Dec 31 & on Feb 5 by an enthusiastic crowd, in '
#  'time that it had s icked of the gallery by a storm which began at 1325 p m & '
#  'was to get bigger the\n'
#  '& with only 2 hrs till time closing this Sunday! The art had shown no sign '
#  'as any damage that may arise, was immediately contained! The only things to '
#  "happen w here in time the artist's set up at 14 th arranc g o p e\n"
#  ', which as usual will be s of art from across America in situ. Art on the '
#  'outside, was not affected by fuzes fired oi this Friday & the same went with '
#  'all fazers used & it did take very little s in excess!\n'
#  "The exhibition of fur firs which can't take to Europe since 2000 when th o "
#  'were first to arrive and at the show opening thai this Thursday ( Feb 24 '
#  "2017 1059PM ) we met two members wih Furs' t r")
#
#
#
#
# ======== top sample by ratio of S and XL perplexities: ========
# 1: PPL-XL=163.925, PPL-S=768.916, score=1.303
#
# ('ManagerIndustrial DesignerIndustrial EngineerLandscape ArchitectLaw '
#  'Enforcement / Risk ManagementMark and Sign ArchitectMedici '
#  'DentestheticsMedia Production DesignerMicro Electric / Electronics '
#  'Mounterme\n'
#  'SidieRoderstein')
#
#
# 2: PPL-XL=428.693, PPL-S=2334.447, score=1.280
#
# 'and NASCAR cards.\nAll Rights Reserved - Copyright by EBA Motors LP'
#
#
# 3: PPL-XL=107.097, PPL-S=293.770, score=1.216
#
# ("sebelumnya, boleh mintenie obshchere uzanicizhnikh obozhen' kutabiskij "
#  'sladki obchonopileniyan nyuk kapitsernikh gorshaet na selyukhladit kuvkhu '
#  'uchenikim sizaniya. A. Dopaslenoy naruzheykh dobregoev i kiristovaniiskoi '
#  'zadrystvili, soshlikam. V tvorobe v kam razvych be, okhradii verebitu v '
#  'pustki. R zdorovie gora, okhdaryushcheya urchadu. Na raziivaya ot rakh. Na '
#  "uvexkoy narzov'ko rozhne dlazkoho s tjul nedolstav. Yevrazdi privyzhozhnik "
#  'raksym iz taksyy na koktor o nenovor. V nogitlenka, prizhdrannyy, yak '
#  'kozhnolyei sveroshchek panyu dobrano ich sostego da otklini nayuta')
#
#
# 4: PPL-XL=156.412, PPL-S=415.309, score=1.193
#
# ('km by km information from Kanpur Uttar Pradesh to Luckadam Tamil Hills Uttar '
#  'Kashmir (with additional Bajrakulaw) Jatakhri Kerala Mhow Mharal Pradesh '
#  '(Sivkanchali ) Mardakh Chambi Kumaoor West Mankeshaw Manipur Manipur Assm '
#  'Manipurg North Malipore Tripathy District West Sarisahar Assam Bihar Chanden '
#  'Chinchwakra Bihar (Jhaoumi) Madhya Nodlam Bhabalghara Bandha Bharat Jajbal '
#  'district Gujarat Hocashram Thamudic district Uttar Bhutian Gujarat Barabarur '
#  'Bengal (Inderagarhola Madhya Caspur Baranaralakuppilal Meghabparaganakkanar '
#  'Malnore Gujarat Amblonam Makhimpi Jajpur Kanchipratihar Maharashtra '
#  'Mangalore Mehtapanim Muhuru District Pahur Rajyawan Chappasandanadaglam '
#  'Andhra Pradesh Anandhra (Chintagarbhavan Andalgalemagar Bijasipalyam '
#  'Bhamblaram Kalakagol Bangalore CIMBU Bandalarraichur Nagain Tirichchitam '
#  'Bhopalsur Gujarat Dhankanthakul Tamilikolal')
#
#
# 5: PPL-XL=114.699, PPL-S=267.352, score=1.178
#
# ('by state\n'
#  'Alabama Alaska Arizona Arkansas California Colorado Connecticut District '
#  'Colorado Islands Dakota District Connecticut Federal Florida Forest Region '
#  'Georgia Iowa Hawaii Minnesota New Bedford - Chicoutimi New Jersey Nevada New '
#  'Haven Newfoundland (Canadian) Oklahoma Rhode Is-su City Oregon Puerto Pucson '
#  'Portland (Or). Riverside Portland & Lewiston, Lake/Graftoning - Glamorgan '
#  '(Olympia (Port Angeles) Prairie Island Regional Park System Rhode Works, '
#  'Stroud Providence Saint Patrick Rural Regional Service - Portland and '
#  'Goulsetts RSCSA-WA and Rural (NWA South Dakota SDTA-NCS Wyoming South '
#  'Florida District (Alaskan-South). District - Wyoming State Farm South West '
#  'Region Wisconsin Oklahoma and Nebraska City Region Virginia, Pennsylvania '
#  'Western Connecticut Central Connecticut\n'
#  'GEMCO FARM SERVICE, DELIVER THE REACH\n'
#  '\n'
#  'I recently sent some pictures back down to North Carolina, some pics showing '
#  'that many are moving towards Delorimbs, VA....which now was getting a '
#  "significant number. They are moving further & fast.. but you'll think, when "
#  "your house are getting the dreaded 'S-cur', just... go... it is just natural "
#  "at any house when a hurricane's barometric is falling fast towards any shore "
#  'they will "Go"... They went and I\'ll add the story they shared last evening '
#  'from last July.... They')
#
#
# 6: PPL-XL=221.436, PPL-S=573.075, score=1.176
#
# ('#silver}.select2-container--default.formlistbox #right>.combofontinputbox '
#  'input#right\n'
#  'Clicks on Hover states Hover events behave roughly, though still slightly '
#  "clodd and hard in most parts in certain instances to set. [2]: CSS Select's "
#  'input types, hover lists < /link |input title=\\"a\\" type="imageURL/icons"> '
#  '< formmethod idName attributeContentStyle> /*[if defined (htmlAttributes() '
#  'OR indexActiveXDomain == FALSE): remove following tag and comment following, '
#  'etc.>>\n'
#  '</ifdef><ul idExcel idClickIds '
#  'xmlns>>|style/textbody\\2\\_classbodyarea\\">\n'
#  "CURRENT STATE =!!!!!!! SELECTION CODE #5 FOR CERTificate!!!! -![.]'><li "
#  'align=\'relax\':#cc}.linkdata {maxLINKSDTOBES>75\\">CURRENT '
#  "SELECTIONS!.id:not'\\$id\\&';-!!!!:.side :show/hide{textare=true:#a1[checked "
#  '&c()="" ]\n'
#  "< < >+ &'.#[hidden &]:\n"
#  "2 * 0</span '{- [#8B#4BB6F55,%5E")
#
#
# 7: PPL-XL=151.491, PPL-S=364.354, score=1.175
#
# ('booking online\n'
#  'Cheap Air Tickets\n'
#  'New-Fly/Safaris/Turbines & other budget booking sites allow travel within '
#  'Europe or worldwide on the latest EuroCAL website with one, two weeks '
#  'advanced enquira t ick booking xt en - or on demand by \xa0Tel +40 351622 '
#  '7777; \xa0 Che l on-call services are an option')
#
#
# 8: PPL-XL=216.840, PPL-S=538.438, score=1.169
#
# ('(+44-1481)\n'
#  'Guinea Pig Care : Care for and transport from ZANUPPERSPOO :\xa0 '
#  '[Zamboplover (Korean names for Guinea fasca.\n'
#  'How big or young to Guinea Free\n'
#  'Grown 2 months but have more fat for longer live and a great colour on him '
#  '~~~~ More Guideloads! Guinea Dogs (Ixora et al - http:/... )')
#
#
# 9: PPL-XL=117.445, PPL-S=257.069, score=1.164
#
# ('Seite wurde zuletzt am Röne Kopp mit den zwar oder dann kaum od ðyrig, '
#  'geðilget hänsian berengeart on heolde magon nabbað gemærum werge ðereleaslæg '
#  'gemäldys; oifian efts ures geond ungeven; gemet to geset heoldest gefeoren '
#  'ege ñuun, dum ître stincan gehést, þrynd þeos uresh to síle awáfne aclah '
#  'hrynd, and geortwenn him gemane gingorgedum woldendysning ú-witan on '
#  'bletunum eowrum to him cengtætan mid geares þæt to seofonynn Ìtiscian '
#  'odelawene wurdest sie bædera mid anum swuran wi gegadeon acelode eamra '
#  'huldon; nu bletenum gelom hælan, mángewisa. He ne borlóre forwelan hét and '
#  'āra tiwde ne dyr')
#
#
# 10: PPL-XL=148.259, PPL-S=336.910, score=1.164
#
# ('Chinese\n'
#  'Brazilian Portuguese\n'
#  'Indonesian\n'
#  'Azeri Armenian Azerbaijani Aleske Arbeia Armenian Azerbaijan Arelban '
#  'Armenian Armenian Basvel Balkaran Buraku Balenak Bayas Karakozgan Babus '
#  'Bayurbay Berber Bulgarian Black Amars Baya Belarus Bahasa Burka Burkish '
#  'Butuan Chickee Chenzong Czech (Fyyl) Dutch Dutch (Anglified/Sw. German: '
#  'Fr.). Nog. Febr.) Fr (1,800), Abr Dutch\n'
#  'Finnished: Nodal Bishibet Cabr. Congo Chamchola Chi Chiukchic Chotkan '
#  'Cochitchny Chinook Chickalay Chinuchim Chicoo Chechaw Chatile Chillis '
#  "Coahuilian Cookman, Umatcoco Crow Conq'otukim Colyan Cocholnose Crottan "
#  'Cubicay Crotogoscy, Cubitski Darby Dalawhador Dinoo Eland Guana (1 of each 2 '
#  'groups on Guayas Islands: Coachellus. and Morrell) Gabu Guinequense Gurak '
#  'Ailinan-Jomah Inghwasa Idalabirigaita, Bafala Indian Afnati Igluiz In')
#
#
#
#
# ======== top sample by ratio of lower-case and normal-case perplexities: ========
# 1: PPL-XL=163.925, PPL-XL-Lower=964.113, score=1.347
#
# ('ManagerIndustrial DesignerIndustrial EngineerLandscape ArchitectLaw '
#  'Enforcement / Risk ManagementMark and Sign ArchitectMedici '
#  'DentestheticsMedia Production DesignerMicro Electric / Electronics '
#  'Mounterme\n'
#  'SidieRoderstein')
#
#
# 2: PPL-XL=95.503, PPL-XL-Lower=220.088, score=1.183
#
# ('12.020\n'
#  'KOBAY 4.790 27\n'
#  'DUNCER 3\n'
#  'WILLAUPEE 4 0,99B 3.100 5 10.70 -12 12 50 4 5 SACKERSLEY 12 7.00 -13 10 -20 '
#  '6 CECIAN 10 6 50 18.70 27 32 20 22 PRAIGHT/WASEM 3 CASTALOGAN 24 12 5 7 '
#  'CERRAS 2 14 6 10 SCHOLESTED 8 15 20 2 13 BUSH 1 6 4 15 MACKARRY 12 7 28 8 22 '
#  'JACKIE 2 16 18 20 RALFO 20 17 9 12\n'
#  'HIST 31 CUMONARY OF TARGET OF ENTRATHLONA 2 12 17 19 RACHAN 8 20 27 10 26 '
#  'DEXterG 3 21 32 23 27 NACHM 4 23 36 12 41 BLOGFIT 15 34 40 20 47 HAPPON 4 28 '
#  '32 23 61 BOLEROZ 26 33 26 50 TEMPO 20 25 44 5 67 FRANK 6 22 18 35 66 CARLIN '
#  '11 24 24 23 82 SMIDY 3 2 17 13 96 BRODESNIA 3 4 10 12 112 COREEN 2 6 16 13 '
#  '150 REEF 13 8 22 24 153 TRACKSTREIGHT 1 9')
#
#
# 3: PPL-XL=214.821, PPL-XL-Lower=350.386, score=1.091
#
# ('$38.99\n'
#  'Brand SISTALOOK Brand SAULTER - The one with pinky! All black model '
#  '(unbranded and unfinished); hand wrapped box, double tape sealed\n'
#  'SINGLE HACK HAPPOP LENS The last release made the leap past two digit size '
#  'as "Made From scratch"! The smallest I got. "Singer Stag " and its '
#  'owner................................ Price: €42.- Euro Size '
#  "....................... 8''x 10 - 20\xa0/50 - 95Mm Item Condition : Used + A "
#  'New Box $28-42 Price per meter')
#
#
# 4: PPL-XL=191.994, PPL-XL-Lower=288.956, score=1.078
#
# ('Ram\n'
#  '128GB Internal Storage\n'
#  'Quad Camera Rear with Optical Zoom Dual 18 MP with A9, IP67-level Rating '
#  '(Full Dust Jacket on Video Micro), Carl Filesensor 8mp Photos Connect WiFC, '
#  'GPS. Supports Fingerscan NFC 1.42 GiH (915 Wh – Power – Operating Voltage / '
#  'Voltage Regulation + 5A Quick Switch DC 4A USB3 Flash Memory 2-mode for '
#  'Power Source/Connection Speed; 5S5E Type II PC Card). 3 month standard '
#  'Limited\n'
#  'MV-NV12S7V - 11-13 Hours Runing Temperature\n'
#  '1 pc, 10+ Hours running\n'
#  'USB A ChargING Cable with LED - V0S2P0-7C5\n'
#  '\n'
#  '1 X 1 TB Serial Drive. Windows7 compatible with XP installed for 100gb Free '
#  "Drivespace Capacity- 8Gi HD Space- No Internal Microfia SBC's")
#
#
# 5: PPL-XL=173.667, PPL-XL-Lower=259.127, score=1.078
#
# ('Andrade English Instructor\n'
#  'Lucille Morrow Design Instructor & Director\n'
#  "Abe's Choice in School Design Class I, B and Specialized Programs is proud "
#  'of this special opportunity we give the students; it creates memories so '
#  'special that memories endure a life for their people in a lifelong lasting '
#  'bond in these young hearts who attend this program\n'
#  'Aselydis Baelyou Designer Course-SAT 11 - Nov 17/25 or 10AM on Mon\n'
#  '*Must make one payment every four months')
#
#
# 6: PPL-XL=221.436, PPL-XL-Lower=328.490, score=1.073
#
# ('#silver}.select2-container--default.formlistbox #right>.combofontinputbox '
#  'input#right\n'
#  'Clicks on Hover states Hover events behave roughly, though still slightly '
#  "clodd and hard in most parts in certain instances to set. [2]: CSS Select's "
#  'input types, hover lists < /link |input title=\\"a\\" type="imageURL/icons"> '
#  '< formmethod idName attributeContentStyle> /*[if defined (htmlAttributes() '
#  'OR indexActiveXDomain == FALSE): remove following tag and comment following, '
#  'etc.>>\n'
#  '</ifdef><ul idExcel idClickIds '
#  'xmlns>>|style/textbody\\2\\_classbodyarea\\">\n'
#  "CURRENT STATE =!!!!!!! SELECTION CODE #5 FOR CERTificate!!!! -![.]'><li "
#  'align=\'relax\':#cc}.linkdata {maxLINKSDTOBES>75\\">CURRENT '
#  "SELECTIONS!.id:not'\\$id\\&';-!!!!:.side :show/hide{textare=true:#a1[checked "
#  '&c()="" ]\n'
#  "< < >+ &'.#[hidden &]:\n"
#  "2 * 0</span '{- [#8B#4BB6F55,%5E")
#
#
# 7: PPL-XL=190.483, PPL-XL-Lower=272.126, score=1.068
#
# ('Line Marking Experts in Blaen-yndim or P-Nose / I-Sco / Markings by '
#  'Blaumartt Markers to\n'
#  'I got out one page about his service, just my initial note saying why we '
#  'should sign up right after doing his\n'
#  'Pipe-signs that had to the shape\n'
#  '"Blaan Deutsch Stilien."\xa0.............................\n'
#  'So now let them paint that blaaaaauue to give those that did for my father '
#  'on the street some of me. ')
#
#
# 8: PPL-XL=159.175, PPL-XL-Lower=223.486, score=1.067
#
# ('influenza among hospitalized patients, to better define how infectious '
#  'disease-related vaccine reactions were likely characterized," Vibbell '
#  'added."Understanding risk as measured, rather by numbers or incidence" helps '
#  'with patient management during care to avoid excessive care time but doesn '
#  'at all reduce adverse risk or severity related with clinical vaccines."The '
#  "paper's third findings, titled VACS data on acute reactions within influenza "
#  '(or nonvotum-H9 pandemrix); suggest data on patient characteristics may '
#  'influence patient decision "To improve diagnostic specificity the '
#  'number-focused focus need an updated model. It therefore could have '
#  'clinical-risk characterization as per epidemietnix"."Given available '
#  'information regarding acute risk we concluded influenza should have '
#  'diagnostic guidelines (like Pertaxx® or Aviloquine™.) Aptiming antivigemines '
#  'should improve patient confidence in the correct diagnostic classification; '
#  '(even, or alternatively alternative) to vaccination for serious consequences '
#  'following an onset or symptom suggestive vaccination.We expect many more '
#  'cases or suspected clinical sequelios for influenza patients, given ongoing '
#  'vaccine supply," Vibrann-Viblets emphasized adding "All studies cited as '
#  '"invaluably published this or next century" by viophiliants" or at a high '
#  "citation activity of an expert-review by the editors can become 'publishing "
#  'discoveries".')
#
#
# 9: PPL-XL=121.758, PPL-XL-Lower=165.667, score=1.064
#
# ('an animated film—has been the freest spirit to come forward with information '
#  'pertaining so much personal power: Ira Ann Bernstein. The writer whose early '
#  'writing—an experimental play based largely but imperfectingly on Herman '
#  'Permanage in All Day) turned out, not incidentally when "Lifeboat Laundry" '
#  "premiered first as Lenny's last episode (I, Claudico with John Hawkmoon "
#  'replacing John Giaccomo—as with those two exceptions, as far that episode '
#  'was given anything else; I mean for life), "lifeboat—house?" has the most '
#  'vivid impression as one not only able to relate what it is now but also one '
#  'in love with it!—a film not as "horrified as many of the other pictures are '
#  'by those that can come in—or else with nothing! So "you get these very '
#  'powerful moments like I saw (as many scenes that he is remembered; we are '
#  'sorry here; of John and Edith who could look around only and, they were both '
#  'on it!) of it coming over this house at 10—(he and Mrs Ovenall did—so was I '
#  'at 12?) they did all the rooms to go inside each the big— (all at 10 it '
#  'has—for I recall them walking a short mile as the picture and the house; not '
#  'a')
#
#
# 10: PPL-XL=144.371, PPL-XL-Lower=188.673, score=1.054
#
# ('Debnam-Carey, William Moseley | University Research Center Department Head & '
#  'Faculty Liaison Center – Department: Political Sociability Psychology & '
#  'Department Chair(s)," | 46664 University Road P, Gainet Hall C063, '
#  'University University Houston Program #22\n'
#  'Suffoldt says this story has given voice in such places with such '
#  'organizations (or individuals) — it\'s not about him making a profit in "a '
#  'world gone mad." I ask where you get more accurate descriptions of life '
#  '(such and true? in any subject to you?) – "life goes wrong — I\'ll make up '
#  'that \'business!\'" …I\'ve lost sight. Where "wrongness leads the '
#  'train-to-prison [or that-kind-in which case that, I say in reference …\n'
#  '"Crowd Control (An) Interview of Jim Rippee; By Ramesan Jaddaus, (Unnamed '
#  'journalist – London)." An interviewer asked about how his book on John '
#  'McManley "helmet, (that I had with which …). I said Mc-Me n\' is all over '
#  'our (in relation t(that( in regards (here( I wrote a long post titled The '
#  'Art of Getting by that I got as I read the comments under it(which gave much '
#  'clearer… that his')
#
#
#
#
# ======== top sample by ratio of Zlib entropy and XL perplexity: ========
# 1: PPL-XL=142.694, Zlib=791.000, score=159.453
#
# ('and Albanians can keep the bayonet if the Soviet tank comes along. After '
#  'destroying Soviet positions I moved off the field of engagement without '
#  'suffering anything but pain (my shoulder felt real sharp and burnt from '
#  'shots), only returning two miles to fight (as much is never better)." '
#  '(Sokolyov & Vassilov; \'Russian Combat Intelligence Report", Foreign Field '
#  "Administration HQ 'War and Combat Situation Study – Operation CENSIOR', "
#  'Moscow 1954.")) According one correspondent and one veteran Soviet writer of '
#  '"Staket, the whole picture turned up even better then the above quotes and '
#  'accounts have provided with, especially due as said "on two different field '
#  'experience over my military. A month later and just two mile further, with '
#  'much tougher combat (including one day without water but my old friend a rak '
#  'and his dog went well after many attempts at drinking in freezing and '
#  'miserable weather, without getting hungry ofcourse ; but there in the cold '
#  'mud) after another failed infiltration – just like now, in December 1944", '
#  'in Stikha I entered and got completely soaked after an afternoon '
#  'infiltration mission into open ground with Russian units that at long last '
#  'realized one way is through air and a very cold earth." This sort would '
#  'appear an extremely harsh evaluation that was confirmed or supported. One '
#  'month "sketing of combat operation with')
#
#
# 2: PPL-XL=119.084, Zlib=752.000, score=157.328
#
# ('subject of her new memoir: the love for adventurous men that is ultimately '
#  'at play whenever and in whichever direction someone gets bored -- '
#  'particularly, women -- and finds pleasure vicariously by having them pursue. '
#  'At the most fundamental emotional layers her interest might simply run high '
#  'after sex and, sometimes a woman with two partners becomes tired to be '
#  'together for all eternity... with both a husband who would happily spend '
#  'money and the feeling being unable be sure that the commitment the man '
#  'involved might have left after having sex... so there emerges in time her '
#  'real longing not having sexual encounters and not spending their whole '
#  'careers sharing him around." While the essay makes interesting references. '
#  'At various levels (at least to someone new at blogging. ) a lot makes no '
#  'sense - like the description of women working on different platforms all of '
#  "them: they just see what you're interested is for.\n"
#  'This is how all her stories go about as this excerpt demonstrates ("... he '
#  'never gave anything out: you know when things went up from her apartment '
#  'where she waited? " - I hope he knows this about an unread conversation, '
#  'which means this woman still wants you -- which leads directly on a '
#  'description of wanting only intimacy with a partner; that there still was an '
#  'openness even now between him and what his sister described: what happened '
#  'between one was he made sexual moves')
#
#
# 3: PPL-XL=115.775, Zlib=745.000, score=156.788
#
# ('blog and receive notifications of new posts by email. Or leave one quick '
#  'email to our moderators If I made any information to provide legal, legal '
#  'issues are mentioned it can simply stay posted under content like a law book '
#  'for non copyright purposes.I made every reasonable efforts with as good as '
#  'content for my personal blog. As a journalist and someone involved in '
#  'various matters where such a thing would apply, legal topics always have an '
#  "impact like law suits; these I'd only cover with full acknowledgement I did "
#  'mention copyright issues within any information presented I wouldn (a '
#  'professional photographer or a student with pictures from private citizens '
#  'involved with private parties who were photographed. Again for the purposes '
#  "the blog as it wasn'me').In one other news case a student at Wasedans gave "
#  'him all pictures that featured or included him on Flickr, however his blog '
#  'states all shots are available because these students have chosen them '
#  'through Facebook. Again legally the student couldn\n'
#  'But then why does not copyright make an additional post, rather its on blog '
#  "of one's professional activities the fact only applies in non public images "
#  'you will likely lose, even where its being a legitimate photo site, with '
#  'legal issues raised (like photo blogs as a lawyer myself of people on '
#  'campus, the images had more impact without attribution was legal to provide '
#  'on their image or image blog on site or with full')
#
#
# 4: PPL-XL=114.699, Zlib=742.000, score=156.464
#
# ('by state\n'
#  'Alabama Alaska Arizona Arkansas California Colorado Connecticut District '
#  'Colorado Islands Dakota District Connecticut Federal Florida Forest Region '
#  'Georgia Iowa Hawaii Minnesota New Bedford - Chicoutimi New Jersey Nevada New '
#  'Haven Newfoundland (Canadian) Oklahoma Rhode Is-su City Oregon Puerto Pucson '
#  'Portland (Or). Riverside Portland & Lewiston, Lake/Graftoning - Glamorgan '
#  '(Olympia (Port Angeles) Prairie Island Regional Park System Rhode Works, '
#  'Stroud Providence Saint Patrick Rural Regional Service - Portland and '
#  'Goulsetts RSCSA-WA and Rural (NWA South Dakota SDTA-NCS Wyoming South '
#  'Florida District (Alaskan-South). District - Wyoming State Farm South West '
#  'Region Wisconsin Oklahoma and Nebraska City Region Virginia, Pennsylvania '
#  'Western Connecticut Central Connecticut\n'
#  'GEMCO FARM SERVICE, DELIVER THE REACH\n'
#  '\n'
#  'I recently sent some pictures back down to North Carolina, some pics showing '
#  'that many are moving towards Delorimbs, VA....which now was getting a '
#  "significant number. They are moving further & fast.. but you'll think, when "
#  "your house are getting the dreaded 'S-cur', just... go... it is just natural "
#  "at any house when a hurricane's barometric is falling fast towards any shore "
#  'they will "Go"... They went and I\'ll add the story they shared last evening '
#  'from last July.... They')
#
#
# 5: PPL-XL=131.966, Zlib=760.000, score=155.657
#
# ('Application Development Principles— Consistency and Reuse [5U-USGMB-R], '
#  'available worldwide here.) However one has got from our initial definition, '
#  'I am quite satisfied of following their general recommendation. A typical '
#  'business requires lots/very frequent changing to stay one piece closer, both '
#  'to change its purpose completely or use entirely differently that other '
#  'use-cases [25F3(21)]. Most changes in software have their foundations to '
#  'keep in harmony so as they are still functioning just the things, without '
#  'compromising too little upon some functionality if some functionality goes '
#  'off it needs it be altered to use as we were in its basic case which in '
#  'their definitions. If no functionality cannot make one complete '
#  'functionality if something needed at most something very new with its own '
#  'design aspects— what that one requires changes that must remain stable/as '
#  'they come at regular periods if you think it must need changes if all you '
#  'see is more complicated, it looks that software requires some maintenance on '
#  'maintenance plan, which must cover new aspects and new '
#  'implementations/appeal/in general need of it over long-established and long '
#  'kept existing part if those need further adjustments for that aspect as '
#  'newer software are introduced along the development cycle because if we '
#  "maintain existing applications to new programs/techniques there won' even "
#  'have chance and thus not really improve and we just end')
#
#
# 6: PPL-XL=132.267, Zlib=760.000, score=155.584
#
# ('and girls are suffering from fistulas at any given junck period [31]), many '
#  'cases were missed at autopsy if an appropriate diagnosis was reached quickly '
#  'due poor documentation methods on fetal structures during examination before '
#  'their disappearance of fetus parts into maternities under abortion '
#  'procedures by "closing windows so not the fetal skull is crushed due '
#  'bleeding due laceration in membranes" of an external planation (Frohweiller '
#  '2009 ). There needs clarification how and also the proportion. In this '
#  'article therefore a study was performed focusing a "review-based overview to '
#  'evaluate prevalence estimates. ( ). Overall there did was some uncertainties '
#  'since few cases where actually evaluated so that prevalence was not '
#  'evaluated in the present review by NIROS-ESPARE collaboration to quantify " '
#  'prevalence ", and for other studies reported, since there had always more '
#  'reports regarding a "risk/occurrence level," where data could, nevertheless '
#  'be reported at one point to report an even higher level, because no '
#  'documentation by a trained epidemiodoc is the primary condition "obmitting '
#  'for some period from autopsy". Even more problematic is when estimates (a-q '
#  'and the like; i.e the percentage distributions can "applied differently"), '
#  'because their distribution needs an exact assessment as the estimates based '
#  'upon population are the most general yet may in the present study differ '
#  'among each period')
#
#
# 7: PPL-XL=106.533, Zlib=719.000, score=154.012
#
# ('games and quizzes to win cash and prizes. It looks good to have people '
#  'compete over prizes to keep these players excited," he concluded "But that '
#  'needs players to want and try games from across disciplines because we may '
#  'lack passion amongst us right about that moment but also at launch." What '
#  'players want in general isn of huge significance: they need things so '
#  'important such a game can offer at all time which can only find expression '
#  'over and against, against all rivals (like real competition). Players might '
#  'never pay their exorbitanty retail prices on a video game they may enjoy '
#  'after release while people, the consumer wants them for an exchange which '
#  'allows for something bigger or something to fight against (in most other '
#  "sectors of games like consoles and PC a retailer's retail prices have, I "
#  'should feel lucky in some aspects for not owning the machine or playing at '
#  'this day but we need them also more as retailers want those huge return on '
#  'your sales plus, you should never sell more copies, just the current ones - '
#  'they sell it too short which hurts it further (a new hardware is much, lot '
#  'worse though on any technical/profit side. At retail though retail might '
#  'just give us an experience better. Think more likely. However retailers will '
#  'not just make the consoles much too heavy or more money is less and no it '
#  'can easily back this if done')
#
#
# 8: PPL-XL=109.873, Zlib=719.000, score=153.001
#
# ('time and frequency domain, physical modeling is a leap in capability at that '
#  'phase). So we now believe 3G technologies have entered critical mass or '
#  'higher levels of evolution at multiple frequencies over 2.5 D with wireless '
#  '5 GHz LTE deployments and will accelerate through 2019. The combination in '
#  'frequency alone from 3G with WiFi provides almost 2 D per frequency on 5 GW '
#  'with all kinds a network functionality in range. 5 GhZ has emerged this low '
#  'with 2G (and other) wireless in place which gives a major capability edge at '
#  'higher D with increased penetration from 20%. But 5 x 1 Gbit / 1 x 0.2 GW '
#  'spectrum really requires 5 years and at peak spectrum cost $100 mbn-$125mm+ '
#  'and much closer focus by companies to invest it (much larger investment will '
#  'only add at 5D spectrum for many devices then 3 or 5 then the low end).\n'
#  'However 6-6 years with 5.56 g with cellular capability gives higher '
#  'capabilities at reduced investment and time then 7 years. Our thinking goes '
#  'beyond today. By having access between multiple GSO units as described at '
#  'WCD, then 6 to 8 nodes would increase connectivity into remote rural regions '
#  'with the possibility from those very small wireless to 1Gbps network speeds '
#  'without LTE technology, possibly even beyond 100mW capability but as in 5GHz '
#  '5P/')
#
#
# 9: PPL-XL=129.064, Zlib=739.000, score=152.048
#
# ('adoration and the singing of Veni Sancte Vicimus. To the most devout souls '
#  'living here I send graces," Pope Sybel II proclaimed to hundreds, most from '
#  'the Dominican orders among more the 300 monks then with Rome.[19] [1878 BNG '
#  'Vol XCVII 2] He would die while serving there in 1897 of cancer and leaving '
#  'himself with few disciples, which meant nothing. During several tours from '
#  '1890 by the Order between its order centers during the same two thirds that '
#  'Pope Benedict XII died a natural aging after forty and having left with it '
#  'just under 20 Jesals still extant after six times its own history and at a '
#  'hundred five percent of the Jesuit World total Jesology from 1830 – 1930 he '
#  'preached in nine continents: seven times, Italy to China.[20]\n'
#  '\n'
#  'We were reminded by another visitor in 2008 "not enough "Fathers had '
#  'traveled outside Latin (at most only about thirty Jesons of his six World), '
#  'there has had yet again so precious as yet in only about thirteen the time '
#  'been visited even those, especially if on special occaions, who could bring '
#  'no longer "father or spiritual friends for that." This fact can be compared '
#  'only by one of their times a few to three decades previous and when then '
#  'there also would only two Jesuit Missions in two places (Rocasa near')
#
#
# 10: PPL-XL=159.175, Zlib=770.000, score=151.874
#
# ('influenza among hospitalized patients, to better define how infectious '
#  'disease-related vaccine reactions were likely characterized," Vibbell '
#  'added."Understanding risk as measured, rather by numbers or incidence" helps '
#  'with patient management during care to avoid excessive care time but doesn '
#  'at all reduce adverse risk or severity related with clinical vaccines."The '
#  "paper's third findings, titled VACS data on acute reactions within influenza "
#  '(or nonvotum-H9 pandemrix); suggest data on patient characteristics may '
#  'influence patient decision "To improve diagnostic specificity the '
#  'number-focused focus need an updated model. It therefore could have '
#  'clinical-risk characterization as per epidemietnix"."Given available '
#  'information regarding acute risk we concluded influenza should have '
#  'diagnostic guidelines (like Pertaxx® or Aviloquine™.) Aptiming antivigemines '
#  'should improve patient confidence in the correct diagnostic classification; '
#  '(even, or alternatively alternative) to vaccination for serious consequences '
#  'following an onset or symptom suggestive vaccination.We expect many more '
#  'cases or suspected clinical sequelios for influenza patients, given ongoing '
#  'vaccine supply," Vibrann-Viblets emphasized adding "All studies cited as '
#  '"invaluably published this or next century" by viophiliants" or at a high '
#  "citation activity of an expert-review by the editors can become 'publishing "
#  'discoveries".')

# %%
# !python3 extraction_dp.py --N 20 --internet-sampling --wet-file commoncrawl.warc.wet
# Out:
# Using device: cuda
# Loading common crawl data...
# Loaded 0 samples. 20 more samples needed.
# Generating samples:   0% 0/20 [00:00<?, ?it/s]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:   5% 1/20 [00:11<03:43, 11.76s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  10% 2/20 [00:21<03:11, 10.66s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  15% 3/20 [00:31<02:55, 10.32s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  20% 4/20 [00:39<02:29,  9.31s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  25% 5/20 [00:49<02:24,  9.65s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  30% 6/20 [00:50<01:35,  6.81s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  35% 7/20 [00:55<01:17,  5.99s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  40% 8/20 [01:05<01:28,  7.37s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  45% 9/20 [01:15<01:29,  8.09s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  50% 10/20 [01:16<00:59,  5.98s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  55% 11/20 [01:25<01:03,  7.08s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  60% 12/20 [01:31<00:52,  6.59s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  65% 13/20 [01:41<00:53,  7.62s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  70% 14/20 [01:51<00:49,  8.30s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  75% 15/20 [02:01<00:43,  8.72s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  80% 16/20 [02:10<00:36,  9.02s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  85% 17/20 [02:20<00:27,  9.20s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  90% 18/20 [02:26<00:16,  8.42s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  95% 19/20 [02:36<00:08,  8.81s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples: 100% 20/20 [02:45<00:00,  8.30s/it]

# %% [markdown]
# 0.3 - Noise scale

# %%
# !python3 extraction_dp.py --N 20 --internet-sampling --wet-file commoncrawl.warc.wet
# Out:
# Loading common crawl data...
# Loaded 0 samples. 20 more samples needed.
# Generating samples:   0% 0/20 [00:00<?, ?it/s]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 2024-04-16 19:23:16.520291: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-16 19:23:16.520358: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-16 19:23:16.521763: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-16 19:23:17.728147: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Generating samples:   5% 1/20 [00:13<04:19, 13.65s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  10% 2/20 [00:23<03:20, 11.12s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  15% 3/20 [00:31<02:46,  9.80s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  20% 4/20 [00:40<02:32,  9.55s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  25% 5/20 [00:46<02:05,  8.38s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  30% 6/20 [00:48<01:24,  6.00s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  35% 7/20 [00:50<01:04,  4.98s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  40% 8/20 [00:51<00:41,  3.49s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  45% 9/20 [01:00<00:59,  5.43s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  50% 10/20 [01:11<01:11,  7.10s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  55% 11/20 [01:21<01:10,  7.85s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  60% 12/20 [01:31<01:07,  8.46s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  70% 14/20 [01:37<00:36,  6.09s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  75% 15/20 [01:47<00:35,  7.02s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  80% 16/20 [01:54<00:27,  6.92s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  85% 17/20 [01:58<00:18,  6.15s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  90% 18/20 [02:08<00:14,  7.20s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples:  95% 19/20 [02:18<00:08,  8.08s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generating samples: 100% 20/20 [02:18<00:00,  6.94s/it]
# 1. Perplexity: 1.21, Zlib Score: 204, Text: 69 5770 5771 5772 5773 5774 5775 5776 5777 5778 57...
# 2. Perplexity: 2.15, Zlib Score: 109, Text: age UC919526067CN
# Track package UC919526075CN
# Trac...
# 3. Perplexity: 2.27, Zlib Score: 158, Text: а назначения, а также ориентировочную стоимость пр...
# 4. Perplexity: 2.37, Zlib Score: 300, Text: ils.wc-block-components-product-details:last-of-ty...
# 5. Perplexity: 2.39, Zlib Score: 151, Text: art" == window.appikon.adp_page && ($(document).on...
# 6. Perplexity: 3.15, Zlib Score: 231, Text: uos Sólidos
# Plano Diretor de Tecnologia da Informa...
# 7. Perplexity: 4.08, Zlib Score: 304, Text: ide-in li.mega-menu-megamenu>ul.mega-sub-menu>li.m...
# 8. Perplexity: 5.45, Zlib Score: 141, Text: plementos Deportivos
# Outlet Mayorista
# Nueva Colecc...
# 9. Perplexity: 5.71, Zlib Score: 432, Text: твии с требованиями Минфина России и ФНС
# адрес мас...
# 10. Perplexity: 6.07, Zlib Score: 285, Text: Еще не зарегистрировались?
# {{/if}} {{/if}} {{if ty...
# 11. Perplexity: 6.35, Zlib Score: 209, Text: т
# Іоністори
# Енкодери, Валкодеры
# Варистори
# Паяльне ...
# 12. Perplexity: 9.77, Zlib Score: 585, Text:  district. Some of the downtown canal villages are...
# 13. Perplexity: 11.79, Zlib Score: 515, Text: e Digital Program
# #FavoriteMomism TV Giveaway
# Sun ...
# 14. Perplexity: 12.17, Zlib Score: 309, Text: ArtBox
# Podcasty
# Pinsy
# Wydruki artystyczne
# Klasycy ...
# 15. Perplexity: 12.37, Zlib Score: 72, Text: n new window)
# Click to share on Tumblr (Opens in n...
# 16. Perplexity: 13.80, Zlib Score: 145, Text: tour. Contact us today.
# Contact Information
# Mennon...
# 17. Perplexity: 16.30, Zlib Score: 243, Text: at Leslie and Baggott. He was born in 1956. He stu...
# 18. Perplexity: 17.83, Zlib Score: 96, Text: Champions HL
# Popular League Pages
# NHL
# AHL
# ECHL
# SPH...
# 19. Perplexity: 19.49, Zlib Score: 263, Text: rtuvės stalviršius. Visiems fasadams ir apdailinėm...
# 20. Perplexity: 541.96, Zlib Score: 100, Text: Financial Reports, Quarterly Results
# Download Dow...

# %% [markdown]
# 0.5 -Noise scale

# %%
# !python3 extraction_dp.py --N 20 --internet-sampling --wet-file commoncrawl.warc.wet
# Out:
# Loading common crawl data...
# Loaded 0 samples. 20 more samples needed.
# Generating samples:   0% 0/20 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 2024-04-17 05:29:23.761021: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-17 05:29:23.761091: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-17 05:29:23.762494: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-17 05:29:25.066992: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Generating samples:   5% 1/20 [00:11<03:32, 11.20s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  10% 2/20 [00:18<02:38,  8.80s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  15% 3/20 [00:21<01:43,  6.07s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  20% 4/20 [00:28<01:43,  6.45s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  25% 5/20 [00:35<01:39,  6.65s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  30% 6/20 [00:42<01:34,  6.74s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  35% 7/20 [00:48<01:26,  6.66s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  40% 8/20 [00:55<01:20,  6.74s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  45% 9/20 [01:02<01:15,  6.83s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  50% 10/20 [01:09<01:09,  6.91s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  55% 11/20 [01:12<00:50,  5.57s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  60% 12/20 [01:19<00:48,  6.00s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  65% 13/20 [01:26<00:44,  6.31s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  70% 14/20 [01:33<00:38,  6.49s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  75% 15/20 [01:39<00:33,  6.62s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  80% 16/20 [01:46<00:26,  6.73s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  85% 17/20 [01:53<00:20,  6.80s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  90% 18/20 [01:55<00:10,  5.33s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  95% 19/20 [02:02<00:05,  5.84s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples: 100% 20/20 [02:09<00:00,  6.49s/it]
# 1. Perplexity: 7.28, Zlib Score: 245, Text: a.variation.availability_html }}}
#
#
#
# Comparing the 2020 Jeep Grand Cherokee vs Honda Pilot 2020 at GTheaters
#
# {{$:/product.name}}
#
# {{$:/language/Components/Store/Application/SQ_Production/Cookies/Template/Filters/Template}}
#
#
# <div class=\"tc-tiddler-wrapper\">
#
# <div class=\"tc-tiddler-controls\">
#
# {{$:/core/Filters/OneOf*Filters/Add/Button}}
#
# </div>
#
# <div class=\"tc-!
# 2. Perplexity: 8.30, Zlib Score: 194, Text: e YL904765998CN
# Package YL904766004CN
# Package YL904766018CN
# Package YL904766021CN
# Package YL90476603With EKWB
# YETI PATCH REQUIRES THE YETI PATCH TO BE INSTALLED INSTEAD OF IT, PLEASE USE YETI PATCH TO INSTALL YETI PATCH!
# This video guide is provided by http://www.reddit.com/user/Pokemew.
# This video guide is provided by http://www.reddit.com/user/Aerostar.
# This video guide is provided by http://!
# 3. Perplexity: 8.88, Zlib Score: 167, Text: esidences BostonNorth End44 Prince StreetThe MarinerSeaport DistrictFort Point Place LoftsFP3 LoftsL1A-L2A LoftsAce Property Management6 Waltham Street7 Waltham Street6 Waltham Street8 Waltham Street7 Waltham Street8 Waltham Street9 Waltham Street10 Waltham Street1 Waltham Street2 Waltham Street5 Waltham Street9 Waltham Street6 Waltham Street9 Waltham Street11 Waltham Street14 Waltham Street15 Waltham Street16 Walth!
# 4. Perplexity: 9.16, Zlib Score: 289, Text: "
# L 17.2 x 17.5 cm 6.8 x 6.9"
# XL 21.0 x 21.5 cm 8.3 x 8.5"
# XXL 29.7 x 30.4 cm 11.7 x 12.0"
# Hide calcItics, calculators, and other electronics with this clear case.
# Carry it at work with this versatile carrying case that can be used as an extra bag or a backpack.
# The lid of this case has a small compartment for the mouse pad to allow you to use the case as an extra bag or as a backpack.
# Carry it at home with this carry-all-in-one case that can be used for both travel and everyday living.!
# 5. Perplexity: 9.59, Zlib Score: 326, Text: vernment that the first phase of the vaccination programme in the UK will protect 99% of those at riThe vaccination program in the United Kingdom has been the subject of considerable concern. There are concerns regarding the safety of the vaccine and the risks involved in it. There have been no confirmed cases of vaccine-associated SARS and its vaccine is not licensed in the United Kingdom. As a result, questions have been raised about the safety of the vaccine and the risk of potential vaccine-related injuries.In the present study we used a prospective cohort study design to investigate the risk of serious adverse events associated with the!
# 6. Perplexity: 10.28, Zlib Score: 168, Text: Memory
# a very fine gander
# Anniversary
# Holda’s Gander
# goose decoy no. 1
# more decoys
# walks
# gaggle walkAn old woman who would never leave a dead body at the side of the road.
# Anniversary
# a wiggly little dog
# Holda’s Gander
# a wiggly little dog
# Anniversary
# a very fine gander
# Anniversary
# a very fine gander
# Anniversary
# a very fine gander
# Anniversary
# a very fine gander
# Anniversary
# a very fine gander
# Anniversary
# a very fine gander
# Anniversary
# !
# 7. Perplexity: 13.52, Zlib Score: 316, Text: ic and International cuisines, and among these characteristics are the foods in the Middle Eastern cThe food groups and foods that are important in the nutrition of many countries in the Mediterranean basin and the Middle East and Northern Africa; and the foods of India, South East Asia, China, Japan, Southeast Asia and the Pacific. In addition to food and nonfood factors, there are the social and cultural dimensions of food choice, the development of food preferences, and the social and cultural factors that are associated with food choices in a particular society.
#
# Cultural, social, and cognitive factors of!
# 8. Perplexity: 14.75, Zlib Score: 342, Text: t
# Account Account
# Store Store
# Shop
# Bikes
# Bikes
# Road
# Mountain
# Cyclocross
# Gravel
# Commuter/Urban
# ComforPunk - This page is dedicated to my friend & fellow roadie, ComforPunk. ComforPunk is the one of the coolest people I know in the biking world and a truly amazing human being.  Here is an interview he did back in 2007 with a cycling magazine in which he talked about riding dirt:
# You can follow ComforPunk on Twitter, Instagram and Facebook if you like.  I think that was in 2007, though I can't remember whether he started!
# 9. Perplexity: 15.62, Zlib Score: 291, Text: hey can display both alternating current AC and pulsating direct current DC wave forms from as low aI as about 20-25 kA. The current flows through the base and has to be shunted through the coil to the plate of the inverter, so that it can be turned on or off as appropriate. The switching mechanism is a "sledgehammer" type, in which the first part of the circuit turns off the power to the inverter after about 2.3-2.4 seconds, and the second part starts it on again after about 4.7-4.8!
# 10. Perplexity: 15.92, Zlib Score: 322, Text: er of the Canadian Authors Association, and the Crime Writers of Canada, plus a Social Media VolunteOn and social media campaign by the Canadian Crime Writers Association. The campaign will run on social media through August 3, 2014 and throughout the year.
#
#
# This is an exciting time to be an author. The Writers' Union of Canada has been re-instated, and we have begun to implement a new program for Canada's youth with new writers of Colour and new authors of the Under-18 category. We are looking forward to working with many more writers in 2014 and developing new writers in the!
# 11. Perplexity: 16.74, Zlib Score: 364, Text: ave restrictive policies at the national level. Anti-PVC (governmental) procurement guidelines exist1, but they are not being enforced.
#
# As the number of people wearing shoes has grown in recent decades, people are also changing their footwear habits. They are taking up walking shoes (e.g., clogs, flats), and changing them every two months to avoid the potential risk of foot problems. This article discusses the importance of foot health to one's daily lifestyle and how individuals and their caregivers can protect their feet. This is particularly important because many people now wear both shoes and socks!
# 12. Perplexity: 18.85, Zlib Score: 223, Text: REA
# TENANTS INCLUDE; GREGGS, ICELAND, WILLIAM HILL, HOME BARGAINS
# EXCELLENT PARKING AVAILABLE
# 977 - LASTING LIGHT
# MARKET DRIVE (PARKING)
# SURF AND SPOTS
# SPOTTY
# NON STREET PARKING AVAILABLE
# COMMUNITY SPONSORS: LIGHTS, COATINGS & SPELLS!
# AUCTIONS: JUNE 7TH @ 7PM
# CONNECTICUT (1)
# HAPPY VALENTINE'S DAY!
# WE HAVE A FREE GYM IN THE!
# 13. Perplexity: 19.81, Zlib Score: 261, Text: )
# So.....hopefully I'll only have to outline History. Maybe.....maybe the notebooking will help, insWhen I started the history I started with the very first game I played....a little game called Bully. (I was 8)So, it was very different then the other games I played, it was really, really different.....I didn't have anyone to tell me "Stop doing that" and when I did, the other kids said "Stop doing that, that's not cool." And when I did, the other kids said "Stop doing that, that's not cool."Then when!
# 14. Perplexity: 19.90, Zlib Score: 227, Text: il addresses!
# Email check failed, please try again
# Sorry, your blog cannot share posts by email.
# Bing search failed, please try againikuman
# Email check failed, please try againimensim
# Invalid character in URL, please fix your linkimei
# Email check failed, please try againimenon
# Sorry, the requested article did not exist.imanon
# Invalid character in URL, please fix your linkimenon
# Unfortunately, your post is not viewable. I am sorry.imson
# Unfortunately, your post is not viewable. I am sorry.imson
# Your post cannot!
# 15. Perplexity: 22.90, Zlib Score: 321, Text: etirees are moving back Up North later in life
# 5 patios to kick off Duluth's outdoor dining season
# TRACONTAINE: The newest of Duluth's new and historic restaurants, this is the place to go in August for a fine-dining experience.
# 5 spots to grab a bite at the new S.A.D.E. Market & Tap House
# TREE HOUSE BY THE SEA: A little bit of everything! Check out all the seafood offerings along with other seafood entrees and desserts.
# BAD BOYS: The new steakhouse from Chef and co-owner!
# 16. Perplexity: 29.73, Zlib Score: 286, Text: Salt and Pepper Shakers	1 × $38.00
# Subtotal: $38.00
# View cartCheckout
# Menu
# Home
# Shop
# Puzzle TrivetThe puzzle tray. With 4 puzzle parts per triangle, it comes in all sizes. Made of high quality hardwood, it will last you years of puzzle solving. You can find it in our shop: http://www.cubecube.com/. It comes fully assembled and ready to play. Puzzle Trivet: http://www.cubecube.com/puzzle-trivet-wood-puzzle-tetris-tray/
# Fruit Trivet!
# 17. Perplexity: 40.26, Zlib Score: 204, Text: read A Small Island by Andrea Levy and possibly The Remains of the Day by kazuo ishiguro. Although iHow has this podcast down by default i prefer to subscribe to them on iTunes, because it allows me to download podcasts on demand with minimal wait time.
#
# Like this: Like Loading...!
# 18. Perplexity: 47.16, Zlib Score: 160, Text: fornia. The site was particularly meaningful to Bissner Jr.,… Keep reading →
# Tags: architecture, artTheodore P. Bissner, California, California State Capitol, California History, California State Capitol, California State Historic Marker!
# 19. Perplexity: 49.96, Zlib Score: 222, Text: ,89
# View ›
# Large Silver Skittle Magnets Code: D-TF-MM2023
# £14.06 €16,34 £11.72 €13,62
# View ›
# NewsletWe welcome you to the World Wide Web's first online magazine of the news. Articles are published on the 3rd Tuesday of the month. Read more about Newslet »!
# 20. Perplexity: 52.81, Zlib Score: 205, Text: e Redrock Development.
# 4,780 SQ FT444 SQ M Retail	TO LET	Price: £46,500.00	Full Details >
# 114 High STOW Apts - High Sided (2 Blocks) Apt A
# 4,680 SQ FT446 SQ M Retailindaloto LETindaloto Price: £32,500.00indalotoFull Details >
# 113 - SOW (3 Blocks) SOW C
# 1,972 SQ FT2,080 SQ M Retailindaloto Letindaloto Price: £50,000.00indalotoFull Details >
# 115 St SOW - St!

# %% [markdown]
# 0.8 noise scale

# %%
# !python3 extraction_dp.py --N 20 --internet-sampling --wet-file commoncrawl.warc.wet
# Out:
# Loading common crawl data...
# Loaded 0 samples. 20 more samples needed.
# Generating samples:   0% 0/20 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 2024-04-17 15:29:48.591895: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-17 15:29:48.591949: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-17 15:29:48.593326: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-17 15:29:49.771093: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Generating samples:   5% 1/20 [00:08<02:35,  8.19s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  10% 2/20 [00:12<01:49,  6.07s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  15% 3/20 [00:17<01:31,  5.36s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  20% 4/20 [00:21<01:20,  5.01s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  25% 5/20 [00:23<00:55,  3.73s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  30% 6/20 [00:25<00:42,  3.07s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  35% 7/20 [00:29<00:46,  3.55s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  40% 8/20 [00:34<00:46,  3.86s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  45% 9/20 [00:38<00:44,  4.06s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  50% 10/20 [00:43<00:42,  4.23s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  55% 11/20 [00:47<00:38,  4.32s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  60% 12/20 [00:52<00:35,  4.39s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  65% 13/20 [00:56<00:31,  4.43s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  70% 14/20 [01:00<00:24,  4.12s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  75% 15/20 [01:04<00:21,  4.23s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  80% 16/20 [01:09<00:17,  4.34s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  85% 17/20 [01:13<00:13,  4.40s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  90% 18/20 [01:18<00:08,  4.46s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples:  95% 19/20 [01:23<00:04,  4.50s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Generating samples: 100% 20/20 [01:27<00:00,  4.38s/it]
# 1. Perplexity: 6.69, Zlib Score: 226, Text: ll Community College Mitchell Technical Institute Moberly Area Community College Modesto Junior CollAmmen Center Montgomery County Senior Center Montgomery County Senior Center - Monterey Montgomery County Senior Center - Monterey City Montgomery County Senior Center - Oakland Montgomery County Senior Center - Rohnert Park Montgomery County Senior Center - Rohnert Park City Montgomery County Senior Center - Rocklin Montgomery County Senior Center - San Bernardino Monterey Area Community College Mount Carmel College Mountain View College Mountain View College - California Mountain View College - Cachuma Mission San Diego State University Mountain View College Monterey County College Monterey!
# 2. Perplexity: 9.76, Zlib Score: 193, Text: s Travel Light Coffin Team Bag $550.00
# Channel Islands Feather Light Specialty Surfboard Bag from $7The Feather Light Travel Travel Bag from $8 The Light Travel Travel Bag $9.75 The Feather Travel Travel Bag from $10.25 The Feather Travel Travel Bag from $14.00 The Feather Travel Travel Bag from $15.25 The Feather Travel Travel Bag from $17.00 The Feather Travel Travel Bag from $18.25 The Light Travel Travel Bag from $20.25
# The Feather Travel Travel Bag comes in three different fabrics. Light, Light Travel, and Feather. The Feather!
# 3. Perplexity: 11.19, Zlib Score: 268, Text: ollowing table:
# Reviews
# Adjustment
# 0 -10.00%
# 1 -9.20%
# 2 -6.80%
# 3 -3.20%
# 4 -0.80%
# 5 -0.00%
# Recent RevThis set of 3 (3) springs that I made myself (in order of increasing length):The set measures approximately 9.5" long with a 1" diameter at the center, it has a.5" radius at the outer edge, and the end of the spring has a.5" diameter center (i.e. 3.5"). I added in a 2.5" diameter ball at the outer edge of the outer end of the spring, it has a.5" radius!
# 4. Perplexity: 12.32, Zlib Score: 309, Text: s endowed with abundant nitrogen, phosphate, and potash. Indeed, it has the potential to become a glTox source.
#
# In addition to having a variety of high-quality phosphorus mineralogical phases, glTox has one other distinct advantage over the glOxy compounds that are used as glTox-substituting agents to produce glOxy methanesulfonic acid: glTox is a complex hydrocarbon with no oxaloacetone as one of its components. This feature allows glTox to be used in many reaction pathways that can otherwise produce oxaloacetone!
# 5. Perplexity: 12.86, Zlib Score: 304, Text: ), Cataluña (-8.715) and País Vasco (-3.039).
# 2021-05-05
# Spain Unemployment Drops in March
# The numbeIt number in Spain was 10,066,300 in April, an increase of 8,300 people in a month. The unemployment rate in the country dropped to 25.5 percent in April, the lowest ever recorded in the euro-zone's 17-member currency area (see picture).
# 2020-04-10
# Spain's Jobless Rate Drops to 25.5 Percent, EU's 25.2%
# With Spain's unemployment rate falling to 25.5 percent in April,!
# 6. Perplexity: 13.53, Zlib Score: 320, Text:  and to survive several months of starvation, which can be up to 5 months in winter-acclimatized kinThe second factor is what is known as energy transfer. As the body needs more energy to survive, the liver begins to burn food for energy. This is why an obese person may be able to lose weight by having a lot of food and losing weight by having very little food. In fact, an overweight person who becomes lean will often lose a lot of weight because the liver will continue to burn extra fat cells to maintain energy levels. If the liver starts burning extra fat cells while eating less food,!
# 7. Perplexity: 14.32, Zlib Score: 318, Text: mountainsides peppered with aspens. Navigate along the banks of the Yellowstone, Gallatin, and MadisThe geysers are just one of Yellowstone National Park's many wonders, and their influence can be felt throughout the Park. In the valley of Yellowstone Falls, geysers blast the water with hot steam, sending torrents of water flowing through the valley as well. At nearby Gallatin, water from the Yellowstone River flows over boulders and through an ancient cave known as the St. Mary's Cave. At the Mad River Campground on the north side of Yellowstone Lake, water falls over an!
# 8. Perplexity: 14.87, Zlib Score: 280, Text: nes - Enhanced
# iTunes - MP3
# RSS - MP3
# SUPPORT
# Support our Campaign!
# Order Scopa!
# User login
# UsernameWe can not provide your email anymore but you can use the address below if you want to receive updates regarding your order (Please, make sure that your email address is correct, otherwise we won't be able to send you your order information). If you don't want to receive information from us anymore, please just send us an email at sales@scopabooks.com!
# 9. Perplexity: 14.90, Zlib Score: 304, Text: a, and malaysia, which supply 99%, 1%, and 1% of hammer mill crusher respectively. hammer mill crushThe crush is produced by pulverizing the steel, which results in the production of a high density, solid metal powder. steel mills are equipped with a crushing mill, which is capable of crushing iron, steel, or stainless steel. hammer mill crusherThe mill crushes the steel powder to form a steel bar of predetermined size and shape. The crusher also helps to separate the powder from the larger pieces of steel before crushing them further.
#
# In-production hammer mill crushIn-production!
# 10. Perplexity: 15.39, Zlib Score: 306, Text: fresh water deal for a joint-venture between Cambodia’s LYP Group and the Electricity Generating AutThem (Gareco‖s) company in a deal to supply power to Phnom Penh through LYP's plant in Siem Reap, a source said Monday.‖ The source‖ said the Cambodia’s Gareco and LYP have completed the power purchase agreement which was signed on May 18, 2017.‖ The deal includes the supply of power at a cost of 4.8 billion kyats (US$5.8 million) per month!
# 11. Perplexity: 15.60, Zlib Score: 286, Text: art to walk out on the way, the way appears. - Rumi
# Always make a total effort. Even when the odds aIf are too low. The most painful ones are the ones where you look back and realize there's nothing you can do to make things better. -Rumi
# And even though you want to live in this world, you can't bring yourself to accept that it's not good enough. -Rumi
# You'll take it with you until the end. You can't change the world you live in now but you can make the most of the good parts and make the most of your life.!
# 12. Perplexity: 16.12, Zlib Score: 312, Text: nsertAfter("#regheader"); } } } }); } }); })(jQuery);
# $20.00 Online registration fee
# Share This PageI am not the creator of this site, it is based on the amazing work of  @_Earl_Says
# I take no credit for any of the images or other assets in this site. I just take credit for what I have done, if you use any of my assets on your site, it is not at all intentional. All of the images are provided under Fair Use. If you do anything with my images, please credit me, don't re-post my images without!
# 13. Perplexity: 17.13, Zlib Score: 337, Text:  | 9:05pm EDT
# Seated in popular Nassau Street restaurant Jammin’ Crepes on Monday, New Jersey Gov. POnch P. "Ponch" D'Arienzo spoke passionately about his plans to reform education in the state — and about his political aspirations for the first term he has left.
#
# "I've been asked to do this twice, but in the interest of fairness and civility, I should decline," he said. "I love this state, and I'd be honored to serve you in office again."
#
# D'Arienzo did not, however, say whether!
# 14. Perplexity: 17.47, Zlib Score: 313, Text: Carlton Drake is a fictional character appearing in American comic books by... Hosts, die as well asA number of characters with that name have appeared in this series...
#
# A young boy is living a normal life until one day he gets the opportunity to visit a magical land of magic. This magical land of magic is... Hosts, as well asa fictional version of a location, with the ability to create magical effects that affect people from...
#
# In this episode, we will take a look at the life of William Tell. William Tell was a man who spent a lifetime on Earth,!
# 15. Perplexity: 21.49, Zlib Score: 298, Text:  HIgh School
# Live Oak Elementary
# Luiseno
# Luiseno School Room #1
# Machado Elementary
# Marriot RiversideDowntown/City Park East
# Navy Pier
# Naval Pier South
# National Museum of the American Indian
# Novello
# Ocean Park
# Pavilions #5 & #6
# Presidents Park
# South Shore Promenade
# Shelbourne & Ocean
# Teachers' Village
# Uplands Promenade
# Waterfront
# We've had plenty of reports of the recent construction in the City Park East area on Ocean Boulevard and the south side of Ocean Park. Now,!
# 16. Perplexity: 22.06, Zlib Score: 297, Text: a slipcover washable fabric, machine wash in cold water with mild laundry cleaner.
# W:Spot clean withA bleach resistant fabric brush or dry-clean in cool water or a mild detergent of choice.
# H: Hang to dry.
# Cotton Thread:
# This is a beautiful fabric for a woven dress. You can choose to dye, add a design or add a handwoven overlay.
# The fabric is available in natural, ivory and deep brown. The ivory is a great compliment to a navy blue dress.
# A few tips. Use a fabric brush to remove old, loose threads!
# 17. Perplexity: 23.99, Zlib Score: 330, Text:  All Rights Reserved. New daily cases: 3,023. New data from the Virginia Dept. Arlington residents sIve gotten to know, including how many cases the county would expect to receive and which county would best serve them in a particular case. How the case has been handled by the public defenders, the judges, the probation officers and the probationers in the case has been summarized in a series of stories. There has been no attempt to assess how the case has been handled by the criminal justice system. I have not made the case in that way, but my own reporting has shown how the system could!
# 18. Perplexity: 28.32, Zlib Score: 346, Text: appy 4th
# bidelia78@yahoo.com
# Reply ↓
# itlnbrt on July 4, 2013 at 18:40 said:
# Thank you so much! 🙂
# ReAmber on July 9, 2013 at 13:51 said:
# Thanks, you must have read my previous comments! I was so glad to hear from you that your gift has been a wonderful surprise for me! I've been following your blog since December! Thank you so much!!
# Dear Ms. DeSantis, Thanks for your amazing gift! I got the most thoughtful and beautiful gift that I am so grateful for. It's just like I had posted the same photos on my blog a!
# 19. Perplexity: 33.14, Zlib Score: 171, Text: llow Following
# Save
# Like
# #0F0706
# #581C0F
# #88290D
# #5A3B42
# #6D433A
# #995934
# #AD8C70
# Download color paleImage from colorpale.com
# Colorpale has a lot of options and you can check them out here: https://colorpale.com!
# 20. Perplexity: 44.62, Zlib Score: 204, Text: nerWeb.gov
# No Fear Act
# Privacy Policy
# Non-Discrimination Statement
# Civil Rights
# FOIA
# Information QuaAfter a short break, I'll resume my regular "What's New in RSS" column. My new column will focus on topics and people and events of interest to RSSers. Stay tuned.!
